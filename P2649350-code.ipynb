# %% [markdown]
# # Configuration

# %%
import os
import sys


os.environ["SPARK_HOME"] = "/usr/spark2.4.3"
os.environ["PYLIB"] = os.environ["SPARK_HOME"] + "/python/lib"
os.environ["PYSPARK_PYTHON"] = "/usr/local/anaconda/bin/python" 
os.environ["PYSPARK_DRIVER_PYTHON"] = "/usr/local/anaconda/bin/python"
sys.path.insert(0, os.environ["PYLIB"] +"/py4j-0.10.7-src.zip")
sys.path.insert(0, os.environ["PYLIB"] +"/pyspark.zip")

#Importing libraries that are required

import csv
import matplotlib.pyplot as plt
import gmplot
import pandas as pd
import numpy as np
import pyspark
from pyspark import SparkContext, SparkConf
from pyspark.sql import SQLContext
from pyspark.sql import SparkSession
from functools import reduce
from pyspark.sql.functions import col, lit, when

#Importing SQL context

from io import StringIO
from collections import namedtuple
from pyspark.sql import Row
from pyspark.sql.types import *
from pyspark.sql.functions import *
from pyspark.sql.functions import sum, col, desc

#Machine Learning library for movie recommendation

from pyspark.ml.evaluation import RegressionEvaluator
from pyspark.ml.recommendation import ALS
from pyspark.ml.tuning import TrainValidationSplit,ParamGridBuilder
from pyspark.sql.functions import explode

# %%
#New Spark Session

import pyspark
from pyspark import SparkConf
from pyspark.sql import SparkSession
spark = SparkSession.builder.getOrCreate()
sqlContext = SQLContext(spark)

# %%
#Sparksession on Recommendation system

spark=SparkSession.builder.appName("Recomendation").getOrCreate()

# %% [markdown]
# # Creating dataframes

# %%
#Creating new Data Frame on Movies dataset which contains large data

Movies_Big= spark.read.option("header", "true").option("delimiter", ",")\
.option("inferSchema", "true").csv("hdfs:///user/imat5322_772599/Assessment_2/movies.csv")

# %%
#Performing action on the movie dataset to check if the data is uploaded successfully

Movies_Big.take(5)
# Out:
# [Row(movieId=1, title='Toy Story (1995)', genres='Adventure|Animation|Children|Comedy|Fantasy'),
#  Row(movieId=2, title='Jumanji (1995)', genres='Adventure|Children|Fantasy'),
#  Row(movieId=3, title='Grumpier Old Men (1995)', genres='Comedy|Romance'),
#  Row(movieId=4, title='Waiting to Exhale (1995)', genres='Comedy|Drama|Romance'),
#  Row(movieId=5, title='Father of the Bride Part II (1995)', genres='Comedy')]

# %%
#Creating new Data Frame on Ratings dataset which contains large data

Ratings_Big= spark.read.option("header", "true").option("delimiter", ",")\
.option("inferSchema", "true").csv("hdfs:///user/imat5322_772599/Assessment_2/ratings.csv")

# %%
#Performing action on the ratings dataset to check if the data is uploaded successfully

Ratings_Big.take(5)
# Out:
# [Row(userId=1, movieId=307, rating=3.5, timestamp=1256677221),
#  Row(userId=1, movieId=481, rating=3.5, timestamp=1256677456),
#  Row(userId=1, movieId=1091, rating=1.5, timestamp=1256677471),
#  Row(userId=1, movieId=1257, rating=4.5, timestamp=1256677460),
#  Row(userId=1, movieId=1449, rating=4.5, timestamp=1256677264)]

# %%
#Checking the count of the observations of Movies_Big Data Frame

Movies_Big.count()
# Out:
# 58098

# %%
#Checking the count of the observations of Ratings_Big Data Frame

Ratings_Big.count()
# Out:
# 27753444

# %%
#Checking the Schema of the Movie_Big Data Frames

Movies_Big.printSchema()
# Out:
# root
#  |-- movieId: integer (nullable = true)
#  |-- title: string (nullable = true)
#  |-- genres: string (nullable = true)

# %%
#Checking the Schema of the Ratings_Big Data Frames

Ratings_Big.printSchema()
# Out:
# root
#  |-- userId: integer (nullable = true)
#  |-- movieId: integer (nullable = true)
#  |-- rating: double (nullable = true)
#  |-- timestamp: integer (nullable = true)

# %% [markdown]
# # Data Exploration

# %%
#Checking for missing data on each column
#Counter is set to 0

i = 0 

#Total saves the sum of the missing data in Movie_Big

total = Movies_Big.count()

print("Total Records = " + str(total))

#Prints the total number of column

print("Total columns = " + str(len(Movies_Big.columns)))
print("------------------------------------------")

#Loop is used to display the count of missing values of each column

#Loop checking every column

while i < len(Movies_Big.columns):                            
    print(str(i+1) + "." + str(Movies_Big[i]))
    print("  Missing Values = ") 
   
    missingvalue = Movies_Big.select([count(when(Movies_Big[i].isNull(),\
                                        True))]).show() 
    
    #Counter is incremented by 1
    i = i+1
# Out:
# Total Records = 58098
# Total columns = 3
# ------------------------------------------
# 1.Column<b'movieId'>
#   Missing Values =
# +------------------------------------------------+
# |count(CASE WHEN (movieId IS NULL) THEN true END)|
# +------------------------------------------------+
# |                                               0|
# +------------------------------------------------+
#
# 2.Column<b'title'>
#   Missing Values =
# +----------------------------------------------+
# |count(CASE WHEN (title IS NULL) THEN true END)|
# +----------------------------------------------+
# |                                             0|
# +----------------------------------------------+
#
# 3.Column<b'genres'>
#   Missing Values =
# +-----------------------------------------------+
# |count(CASE WHEN (genres IS NULL) THEN true END)|
# +-----------------------------------------------+
# |                                              0|
# +-----------------------------------------------+

# %%
#Checking for missing data on each column
#Counter is set to 0

i = 0 

#Total saves the sum of the Ratings_Big

total = Ratings_Big.count()

print("Total Records = " + str(total))

#Prints the total number of column

print("Total columns = " + str(len(Ratings_Big.columns)))
print("------------------------------------------")

#Loop is used to display the count of missing values of each column
#Loop checking every column

while i < len(Ratings_Big.columns):                             
    print(str(i+1) + "." + str(Ratings_Big[i]))
    print("  Missing Values = ") 
   
    missingvalue = Ratings_Big.select([count(when(Ratings_Big[i].isNull(),\
                                        True))]).show() 
    
    #Counter is incremented by 1
    i = i+1
# Out:
# Total Records = 27753444
# Total columns = 4
# ------------------------------------------
# 1.Column<b'userId'>
#   Missing Values =
# +-----------------------------------------------+
# |count(CASE WHEN (userId IS NULL) THEN true END)|
# +-----------------------------------------------+
# |                                              0|
# +-----------------------------------------------+
#
# 2.Column<b'movieId'>
#   Missing Values =
# +------------------------------------------------+
# |count(CASE WHEN (movieId IS NULL) THEN true END)|
# +------------------------------------------------+
# |                                               0|
# +------------------------------------------------+
#
# 3.Column<b'rating'>
#   Missing Values =
# +-----------------------------------------------+
# |count(CASE WHEN (rating IS NULL) THEN true END)|
# +-----------------------------------------------+
# |                                              0|
# +-----------------------------------------------+
#
# 4.Column<b'timestamp'>
#   Missing Values =
# +--------------------------------------------------+
# |count(CASE WHEN (timestamp IS NULL) THEN true END)|
# +--------------------------------------------------+
# |                                                 0|
# +--------------------------------------------------+

# %% [markdown]
# # Cleaning of data

# %%
#Dropping timestamp column as it is not needed for analysis 

Ratings_Big=Ratings_Big.drop("timestamp")

# %% [markdown]
# # Pre Processing of Data Frame

# %% [markdown]
# ## Pre Processing on Movies_Big Data Frame

# %%
#Splitting the title to extarct Year using substring

year1=Movies_Big.selectExpr('title', 'substring(title, length(title)-4, length(title)) as Year')
year2= year1.withColumn("Year",expr("substring(Year, 1, length(Year)-1)"))

#Converting string type of year to integer

year = year2.withColumn("Year", year2.Year.cast('integer'))

# %%
#Displaying the Year column extracted from Title

year.show()
# Out:
# +--------------------+----+
# |               title|Year|
# +--------------------+----+
# |    Toy Story (1995)|1995|
# |      Jumanji (1995)|1995|
# |Grumpier Old Men ...|1995|
# |Waiting to Exhale...|1995|
# |Father of the Bri...|1995|
# |         Heat (1995)|1995|
# |      Sabrina (1995)|1995|
# | Tom and Huck (1995)|1995|
# | Sudden Death (1995)|1995|
# |    GoldenEye (1995)|1995|
# |American Presiden...|1995|
# |Dracula: Dead and...|1995|
# |        Balto (1995)|1995|
# |        Nixon (1995)|1995|
# |Cutthroat Island ...|1995|
# |       Casino (1995)|1995|
# |Sense and Sensibi...|1995|
# |   Four Rooms (1995)|1995|
# |Ace Ventura: When...|1995|
# |  Money Train (1995)|1995|
# +--------------------+----+
# only showing top 20 rows

# %%
#Schema check and Year was string type but now its changed to integer

year.printSchema()
# Out:
# root
#  |-- title: string (nullable = true)
#  |-- Year: integer (nullable = true)

# %%
#Merging Movies_Big with Year

Updated_Movies = Movies_Big.join(year, \
Movies_Big["title"] == year["title"], \
how="inner").drop(Movies_Big["title"])

# %%
Updated_Movies.show()
# Out:
# +-------+--------------------+--------------------+----+
# |movieId|              genres|               title|Year|
# +-------+--------------------+--------------------+----+
# |      1|Adventure|Animati...|    Toy Story (1995)|1995|
# |      2|Adventure|Childre...|      Jumanji (1995)|1995|
# |      3|      Comedy|Romance|Grumpier Old Men ...|1995|
# |      4|Comedy|Drama|Romance|Waiting to Exhale...|1995|
# |      5|              Comedy|Father of the Bri...|1995|
# |      6|Action|Crime|Thri...|         Heat (1995)|1995|
# |      7|      Comedy|Romance|      Sabrina (1995)|1995|
# |      8|  Adventure|Children| Tom and Huck (1995)|1995|
# |      9|              Action| Sudden Death (1995)|1995|
# |     10|Action|Adventure|...|    GoldenEye (1995)|1995|
# |     11|Comedy|Drama|Romance|American Presiden...|1995|
# |     12|       Comedy|Horror|Dracula: Dead and...|1995|
# |     13|Adventure|Animati...|        Balto (1995)|1995|
# |     14|               Drama|        Nixon (1995)|1995|
# |     15|Action|Adventure|...|Cutthroat Island ...|1995|
# |     16|         Crime|Drama|       Casino (1995)|1995|
# |     17|       Drama|Romance|Sense and Sensibi...|1995|
# |     18|              Comedy|   Four Rooms (1995)|1995|
# |     19|              Comedy|Ace Ventura: When...|1995|
# |     20|Action|Comedy|Cri...|  Money Train (1995)|1995|
# +-------+--------------------+--------------------+----+
# only showing top 20 rows

# %% [markdown]
# ## Pre Processing on Ratings_Big Data Frame

# %%
#Extracting the average rating and count of the rating 

Ratings=Ratings_Big.groupby("movieId") \
       .agg(mean("rating").alias("avg_rating"), \
       count("userId").alias("rating_count")) \
       .sort(asc("movieId"))

# %%
Ratings.show()
# Out:
# +-------+------------------+------------+
# |movieId|        avg_rating|rating_count|
# +-------+------------------+------------+
# |      1|3.8866494325899312|       68469|
# |      2| 3.246582912721512|       27143|
# |      3| 3.173981392364453|       15585|
# |      4| 2.874539979926397|        2989|
# |      5|3.0772909396406876|       15474|
# |      6|3.8442108566049575|       28683|
# |      7| 3.371348277890334|       15301|
# |      8| 3.122482131254061|        1539|
# |      9| 3.007529781973477|        4449|
# |     10| 3.431632714743396|       33086|
# |     11| 3.660277594183741|       19669|
# |     12|2.6696507515473034|        4524|
# |     13|3.3396516393442623|        1952|
# |     14|3.4289997075168177|        6838|
# |     15| 2.730976537729867|        3154|
# |     16|3.8023623907394284|       21165|
# |     17|3.9501262626262625|       24552|
# |     18|  3.41207034372502|        6255|
# |     19|2.6420142094488823|       24913|
# |     20| 2.894482610562473|        4658|
# +-------+------------------+------------+
# only showing top 20 rows

# %% [markdown]
# ## Merging of Data Frames

# %%
#Merging Updated_Movies with Ratings Data Frame

Movie_Rating = Updated_Movies.join(Ratings, \
Updated_Movies["movieId"] == Ratings["movieId"], \
how="inner").drop(Updated_Movies["movieId"]).sort(asc("movieId"))

# %%
Movie_Rating.show()
# Out:
# +--------------------+--------------------+----+-------+------------------+------------+
# |              genres|               title|Year|movieId|        avg_rating|rating_count|
# +--------------------+--------------------+----+-------+------------------+------------+
# |Adventure|Animati...|    Toy Story (1995)|1995|      1|3.8866494325899312|       68469|
# |Adventure|Childre...|      Jumanji (1995)|1995|      2| 3.246582912721512|       27143|
# |      Comedy|Romance|Grumpier Old Men ...|1995|      3| 3.173981392364453|       15585|
# |Comedy|Drama|Romance|Waiting to Exhale...|1995|      4| 2.874539979926397|        2989|
# |              Comedy|Father of the Bri...|1995|      5|3.0772909396406876|       15474|
# |Action|Crime|Thri...|         Heat (1995)|1995|      6|3.8442108566049575|       28683|
# |      Comedy|Romance|      Sabrina (1995)|1995|      7| 3.371348277890334|       15301|
# |  Adventure|Children| Tom and Huck (1995)|1995|      8| 3.122482131254061|        1539|
# |              Action| Sudden Death (1995)|1995|      9| 3.007529781973477|        4449|
# |Action|Adventure|...|    GoldenEye (1995)|1995|     10| 3.431632714743396|       33086|
# |Comedy|Drama|Romance|American Presiden...|1995|     11| 3.660277594183741|       19669|
# |       Comedy|Horror|Dracula: Dead and...|1995|     12|2.6696507515473034|        4524|
# |Adventure|Animati...|        Balto (1995)|1995|     13|3.3396516393442623|        1952|
# |               Drama|        Nixon (1995)|1995|     14|3.4289997075168177|        6838|
# |Action|Adventure|...|Cutthroat Island ...|1995|     15| 2.730976537729867|        3154|
# |         Crime|Drama|       Casino (1995)|1995|     16|3.8023623907394284|       21165|
# |       Drama|Romance|Sense and Sensibi...|1995|     17|3.9501262626262625|       24552|
# |              Comedy|   Four Rooms (1995)|1995|     18|  3.41207034372502|        6255|
# |              Comedy|Ace Ventura: When...|1995|     19|2.6420142094488823|       24913|
# |Action|Comedy|Cri...|  Money Train (1995)|1995|     20| 2.894482610562473|        4658|
# +--------------------+--------------------+----+-------+------------------+------------+
# only showing top 20 rows

# %%
Movie_Rating.count()
# Out:
# 54039

# %%
#Rearranging the column

Movie_Rating = Movie_Rating \
.select("movieId","title","Year","genres","avg_rating","rating_count")

# %%
#Removing year from title column

Movie_Rating = Movie_Rating \
.withColumn("title",expr("substring(title, 1, length(title)-7)"))

# %%
Movie_Rating.show()
# Out:
# +-------+--------------------+----+--------------------+------------------+------------+
# |movieId|               title|Year|              genres|        avg_rating|rating_count|
# +-------+--------------------+----+--------------------+------------------+------------+
# |      1|           Toy Story|1995|Adventure|Animati...|3.8866494325899312|       68469|
# |      2|             Jumanji|1995|Adventure|Childre...| 3.246582912721512|       27143|
# |      3|    Grumpier Old Men|1995|      Comedy|Romance| 3.173981392364453|       15585|
# |      4|   Waiting to Exhale|1995|Comedy|Drama|Romance| 2.874539979926397|        2989|
# |      5|Father of the Bri...|1995|              Comedy|3.0772909396406876|       15474|
# |      6|                Heat|1995|Action|Crime|Thri...|3.8442108566049575|       28683|
# |      7|             Sabrina|1995|      Comedy|Romance| 3.371348277890334|       15301|
# |      8|        Tom and Huck|1995|  Adventure|Children| 3.122482131254061|        1539|
# |      9|        Sudden Death|1995|              Action| 3.007529781973477|        4449|
# |     10|           GoldenEye|1995|Action|Adventure|...| 3.431632714743396|       33086|
# |     11|American Presiden...|1995|Comedy|Drama|Romance| 3.660277594183741|       19669|
# |     12|Dracula: Dead and...|1995|       Comedy|Horror|2.6696507515473034|        4524|
# |     13|               Balto|1995|Adventure|Animati...|3.3396516393442623|        1952|
# |     14|               Nixon|1995|               Drama|3.4289997075168177|        6838|
# |     15|    Cutthroat Island|1995|Action|Adventure|...| 2.730976537729867|        3154|
# |     16|              Casino|1995|         Crime|Drama|3.8023623907394284|       21165|
# |     17|Sense and Sensibi...|1995|       Drama|Romance|3.9501262626262625|       24552|
# |     18|          Four Rooms|1995|              Comedy|  3.41207034372502|        6255|
# |     19|Ace Ventura: When...|1995|              Comedy|2.6420142094488823|       24913|
# |     20|         Money Train|1995|Action|Comedy|Cri...| 2.894482610562473|        4658|
# +-------+--------------------+----+--------------------+------------------+------------+
# only showing top 20 rows

# %% [markdown]
# ## Extracting Genres individually

# %%
#Splitting multiple genres using delimiter '|'

from pyspark.sql.functions import split,explode
Genres=Updated_Movies.withColumn('genres',explode(split('genres','[|]')))

# %%
Genres.show()
# Out:
# +-------+---------+--------------------+----+
# |movieId|   genres|               title|Year|
# +-------+---------+--------------------+----+
# |      1|Adventure|    Toy Story (1995)|1995|
# |      1|Animation|    Toy Story (1995)|1995|
# |      1| Children|    Toy Story (1995)|1995|
# |      1|   Comedy|    Toy Story (1995)|1995|
# |      1|  Fantasy|    Toy Story (1995)|1995|
# |      2|Adventure|      Jumanji (1995)|1995|
# |      2| Children|      Jumanji (1995)|1995|
# |      2|  Fantasy|      Jumanji (1995)|1995|
# |      3|   Comedy|Grumpier Old Men ...|1995|
# |      3|  Romance|Grumpier Old Men ...|1995|
# |      4|   Comedy|Waiting to Exhale...|1995|
# |      4|    Drama|Waiting to Exhale...|1995|
# |      4|  Romance|Waiting to Exhale...|1995|
# |      5|   Comedy|Father of the Bri...|1995|
# |      6|   Action|         Heat (1995)|1995|
# |      6|    Crime|         Heat (1995)|1995|
# |      6| Thriller|         Heat (1995)|1995|
# |      7|   Comedy|      Sabrina (1995)|1995|
# |      7|  Romance|      Sabrina (1995)|1995|
# |      8|Adventure| Tom and Huck (1995)|1995|
# +-------+---------+--------------------+----+
# only showing top 20 rows

# %%
Genres.groupBy("genres").count().show()
# Out:
# +------------------+-----+
# |            genres|count|
# +------------------+-----+
# |             Crime| 5117|
# |           Romance| 7434|
# |          Thriller| 8260|
# |         Adventure| 4081|
# |             Drama|24217|
# |               War| 1821|
# |       Documentary| 5124|
# |           Fantasy| 2641|
# |           Mystery| 2776|
# |           Musical| 1115|
# |         Animation| 2670|
# |         Film-Noir|  364|
# |(no genres listed)| 4278|
# |              IMAX|  197|
# |            Horror| 5578|
# |           Western| 1379|
# |            Comedy|15989|
# |          Children| 2753|
# |            Action| 7148|
# |            Sci-Fi| 3462|
# +------------------+-----+

# %% [markdown]
# # Visualisation

# %%
#Importing PixieDust for visualisation

import pixiedust
# Out:
# Pixiedust database opened successfully
#         <div style="margin:10px">
#             <a href="https://github.com/ibm-watson-data-lab/pixiedust" target="_new">
#                 <img src="https://github.com/ibm-watson-data-lab/pixiedust/raw/master/docs/_static/pd_icon32.png" style="float:left;margin-right:10px"/>
#             </a>
#             <span>Pixiedust version 1.1.15</span>
#         </div>
# <div>Warning: You are not running the latest version of PixieDust. Current is 1.1.15, Latest is 1.1.19</div>
#                 <div>Please copy and run the following command in a new cell to upgrade: <span style="background-color:#ececec;font-family:monospace;padding:0 5px">!pip install --user --upgrade pixiedust</span></div>
# <div>Please restart kernel after upgrading.</div>

# %% [markdown]
# ## Analysis on Average Rating vs Total Rating

# %%
display(Movie_Rating)
# Out:
# <style type="text/css">.pd_warning{display:none;}</style><div class="pd_warning"><em>Hey, there's something awesome here! To see it, open this notebook outside GitHub, in a viewer like Jupyter</em></div>

# %% [markdown]
# ## Analysis on Individual Genre

# %%
display(Genres)
# Out:
# <div class="pixiedust" pixiedust="{&quot;prefix&quot;: &quot;851f7c19&quot;, &quot;command&quot;: &quot;display(Genres,cell_id=&apos;8cd819d1d6314d4fb52b300fbb57c75a&apos;,nostore_pixiedust=&apos;true&apos;,aggregation=&apos;COUNT&apos;,handlerId=&apos;pieChart&apos;,keyFields=&apos;genres&apos;,valueFields=&apos;movieId&apos;,nostore_cw=&apos;1098&apos;,nostore_vh=&apos;656&apos;,org_params=&apos;nostore_pixiedust&apos;,nostore_bokeh=&apos;false&apos;)&quot;, &quot;entity&quot;: &quot;Genres&quot;, &quot;options&quot;: {&quot;cell_id&quot;: &quot;8cd819d1d6314d4fb52b300fbb57c75a&quot;, &quot;nostore_pixiedust&quot;: &quot;true&quot;, &quot;aggregation&quot;: &quot;COUNT&quot;, &quot;handlerId&quot;: &quot;pieChart&quot;, &quot;keyFields&quot;: &quot;genres&quot;, &quot;valueFields&quot;: &quot;movieId&quot;, &quot;nostore_cw&quot;: &quot;1098&quot;, &quot;nostore_vh&quot;: &quot;656&quot;, &quot;org_params&quot;: &quot;nostore_pixiedust&quot;, &quot;nostore_bokeh&quot;: &quot;false&quot;}, &quot;sniffers&quot;: [&quot;{&apos;nostore_bokeh&apos;:!!window.Bokeh}&quot;], &quot;avoidMetadata&quot;: false, &quot;include_keys&quot;: [&quot;filter&quot;]}">
#
#   <button class="btn btn-default btn-sm expandButton" data-toggle="collapse"
#           data-target="#pixiedust-output-wrapper-851f7c19" title="Expand/Collapse Pixiedust output">
#     <i class="fa"></i>
#   </button>
#
#
#   <div id="pixiedust-output-wrapper-851f7c19" class="pixiedust-output-wrapper collapse in">
#
#       <div class="pixiedust-toolbar btn-group" role="group" style="margin-bottom:15px">
#
#
#           <a class="btn btn-small btn-default display-type-button" id="menu851f7c19-tableView" title="Table.Next">
#             <i class="fa fa-table"></i>
#           </a>
#
#             <script>
#                 $('#menu851f7c19-tableView').on('click',
#
#             function(){
#                 pixiedust.executeDisplay(
#                     {"prefix": "851f7c19", "command": "display(Genres,cell_id='8cd819d1d6314d4fb52b300fbb57c75a',nostore_pixiedust='true',aggregation='COUNT',handlerId='tableView',keyFields='genres',valueFields='movieId',nostore_cw='1098',nostore_vh='656',org_params='nostore_pixiedust',nostore_bokeh='false',prefix='851f7c19')", "entity": "Genres", "options": {"cell_id": "8cd819d1d6314d4fb52b300fbb57c75a", "nostore_pixiedust": "true", "aggregation": "COUNT", "handlerId": "tableView", "keyFields": "genres", "valueFields": "movieId", "nostore_cw": "1098", "nostore_vh": "656", "org_params": "nostore_pixiedust", "nostore_bokeh": "false", "prefix": "851f7c19"}, "sniffers": ["{'nostore_bokeh':!!window.Bokeh}"], "avoidMetadata": true, "include_keys": ["filter"]},
#                     {'targetDivId': 'wrapperHTML851f7c19' }
#                 );
#             }
#             )
#             </script>
#
#
#
#
#           <div class="btn-group btn-small display-type-button">
#
#             <a class="btn btn-small dropdown-toggle btn-default" data-toggle="dropdown" title="Chart">
#
#               <i class="fa fa-line-chart"></i>
#
#               <i class="fa fa-chevron-down"></i>
#             </a>
#             <div class="dropdown-menu" role="menu" style="white-space:nowrap">
#               <ul>
#
#                 <li id="menu851f7c19-barChart">
#
#                   <i class="fa fa-bar-chart"></i>
#
#                   <span>Bar Chart</span>
#
#             <script>
#                 $('#menu851f7c19-barChart').on('click',
#
#             function(){
#                 pixiedust.executeDisplay(
#                     {"prefix": "851f7c19", "command": "display(Genres,cell_id='8cd819d1d6314d4fb52b300fbb57c75a',nostore_pixiedust='true',aggregation='COUNT',handlerId='barChart',keyFields='genres',valueFields='movieId',nostore_cw='1098',nostore_vh='656',org_params='nostore_pixiedust',nostore_bokeh='false',prefix='851f7c19')", "entity": "Genres", "options": {"cell_id": "8cd819d1d6314d4fb52b300fbb57c75a", "nostore_pixiedust": "true", "aggregation": "COUNT", "handlerId": "barChart", "keyFields": "genres", "valueFields": "movieId", "nostore_cw": "1098", "nostore_vh": "656", "org_params": "nostore_pixiedust", "nostore_bokeh": "false", "prefix": "851f7c19"}, "sniffers": ["{'nostore_bokeh':!!window.Bokeh}"], "avoidMetadata": true, "include_keys": ["filter"]},
#                     {'targetDivId': 'wrapperHTML851f7c19' }
#                 );
#             }
#             )
#             </script>
#
#                 </li>
#
#                 <li id="menu851f7c19-lineChart">
#
#                   <i class="fa fa-line-chart"></i>
#
#                   <span>Line Chart</span>
#
#             <script>
#                 $('#menu851f7c19-lineChart').on('click',
#
#             function(){
#                 pixiedust.executeDisplay(
#                     {"prefix": "851f7c19", "command": "display(Genres,cell_id='8cd819d1d6314d4fb52b300fbb57c75a',nostore_pixiedust='true',aggregation='COUNT',handlerId='lineChart',keyFields='genres',valueFields='movieId',nostore_cw='1098',nostore_vh='656',org_params='nostore_pixiedust',nostore_bokeh='false',prefix='851f7c19')", "entity": "Genres", "options": {"cell_id": "8cd819d1d6314d4fb52b300fbb57c75a", "nostore_pixiedust": "true", "aggregation": "COUNT", "handlerId": "lineChart", "keyFields": "genres", "valueFields": "movieId", "nostore_cw": "1098", "nostore_vh": "656", "org_params": "nostore_pixiedust", "nostore_bokeh": "false", "prefix": "851f7c19"}, "sniffers": ["{'nostore_bokeh':!!window.Bokeh}"], "avoidMetadata": true, "include_keys": ["filter"]},
#                     {'targetDivId': 'wrapperHTML851f7c19' }
#                 );
#             }
#             )
#             </script>
#
#                 </li>
#
#                 <li id="menu851f7c19-scatterPlot">
#
#                   <i class="fa fa-circle"></i>
#
#                   <span>Scatter Plot</span>
#
#             <script>
#                 $('#menu851f7c19-scatterPlot').on('click',
#
#             function(){
#                 pixiedust.executeDisplay(
#                     {"prefix": "851f7c19", "command": "display(Genres,cell_id='8cd819d1d6314d4fb52b300fbb57c75a',nostore_pixiedust='true',aggregation='COUNT',handlerId='scatterPlot',keyFields='genres',valueFields='movieId',nostore_cw='1098',nostore_vh='656',org_params='nostore_pixiedust',nostore_bokeh='false',prefix='851f7c19')", "entity": "Genres", "options": {"cell_id": "8cd819d1d6314d4fb52b300fbb57c75a", "nostore_pixiedust": "true", "aggregation": "COUNT", "handlerId": "scatterPlot", "keyFields": "genres", "valueFields": "movieId", "nostore_cw": "1098", "nostore_vh": "656", "org_params": "nostore_pixiedust", "nostore_bokeh": "false", "prefix": "851f7c19"}, "sniffers": ["{'nostore_bokeh':!!window.Bokeh}"], "avoidMetadata": true, "include_keys": ["filter"]},
#                     {'targetDivId': 'wrapperHTML851f7c19' }
#                 );
#             }
#             )
#             </script>
#
#                 </li>
#
#                 <li id="menu851f7c19-pieChart">
#
#                   <i class="fa fa-pie-chart"></i>
#
#                   <span>Pie Chart</span>
#
#             <script>
#                 $('#menu851f7c19-pieChart').on('click',
#
#             function(){
#                 pixiedust.executeDisplay(
#                     {"prefix": "851f7c19", "command": "display(Genres,cell_id='8cd819d1d6314d4fb52b300fbb57c75a',nostore_pixiedust='true',aggregation='COUNT',handlerId='pieChart',keyFields='genres',valueFields='movieId',nostore_cw='1098',nostore_vh='656',org_params='nostore_pixiedust',nostore_bokeh='false',prefix='851f7c19')", "entity": "Genres", "options": {"cell_id": "8cd819d1d6314d4fb52b300fbb57c75a", "nostore_pixiedust": "true", "aggregation": "C

# %% [markdown]
# ## Analysis on Top movies whose total rating is above 70,000

# %%
#Creating a temporary table

Topmovies=Movie_Rating.registerTempTable("Topmovies")

# %%
#Extracting movies with total rating over 70,000

Topmovies=sqlContext.\
sql("select * \
from Topmovies \
where rating_count > 70000 \
order by rating_count")

# %%
Topmovies.show()
# Out:
# +-------+--------------------+----+--------------------+------------------+------------+
# |movieId|               title|Year|              genres|        avg_rating|rating_count|
# +-------+--------------------+----+--------------------+------------------+------------+
# |    527|    Schindler's List|1993|           Drama|War| 4.257501817775044|       71516|
# |    480|       Jurassic Park|1993|Action|Adventure|...|3.6650338125073576|       76451|
# |    260|Star Wars: Episod...|1977|Action|Adventure|...| 4.120454684348836|       81815|
# |   2571|         Matrix, The|1999|Action|Sci-Fi|Thr...| 4.149695428470046|       84545|
# |    593|Silence of the La...|1991|Crime|Horror|Thri...|  4.15141241652351|       87899|
# |    296|        Pulp Fiction|1994|Comedy|Crime|Dram...| 4.173971387139363|       92406|
# |    356|        Forrest Gump|1994|Comedy|Drama|Roma...| 4.056584913437757|       97040|
# |    318|Shawshank Redempt...|1994|         Crime|Drama| 4.424188001918387|       97999|
# +-------+--------------------+----+--------------------+------------------+------------+

# %%
display(Topmovies)
# Out:
# <div class="pixiedust" pixiedust="{&quot;prefix&quot;: &quot;3c8f4997&quot;, &quot;command&quot;: &quot;display(Topmovies,cell_id=&apos;c1e40852e4924faf8215966b8fbd0b7d&apos;,nostore_pixiedust=&apos;true&apos;,handlerId=&apos;barChart&apos;,keyFields=&apos;title&apos;,orientation=&apos;horizontal&apos;,rowCount=&apos;100000&apos;,valueFields=&apos;rating_count&apos;,nostore_cw=&apos;1098&apos;,nostore_vh=&apos;656&apos;,org_params=&apos;nostore_pixiedust&apos;,nostore_bokeh=&apos;false&apos;)&quot;, &quot;entity&quot;: &quot;Topmovies&quot;, &quot;options&quot;: {&quot;cell_id&quot;: &quot;c1e40852e4924faf8215966b8fbd0b7d&quot;, &quot;nostore_pixiedust&quot;: &quot;true&quot;, &quot;handlerId&quot;: &quot;barChart&quot;, &quot;keyFields&quot;: &quot;title&quot;, &quot;orientation&quot;: &quot;horizontal&quot;, &quot;rowCount&quot;: &quot;100000&quot;, &quot;valueFields&quot;: &quot;rating_count&quot;, &quot;nostore_cw&quot;: &quot;1098&quot;, &quot;nostore_vh&quot;: &quot;656&quot;, &quot;org_params&quot;: &quot;nostore_pixiedust&quot;, &quot;nostore_bokeh&quot;: &quot;false&quot;}, &quot;sniffers&quot;: [&quot;{&apos;nostore_bokeh&apos;:!!window.Bokeh}&quot;], &quot;avoidMetadata&quot;: false, &quot;include_keys&quot;: [&quot;filter&quot;]}">
#
#   <button class="btn btn-default btn-sm expandButton" data-toggle="collapse"
#           data-target="#pixiedust-output-wrapper-3c8f4997" title="Expand/Collapse Pixiedust output">
#     <i class="fa"></i>
#   </button>
#
#
#   <div id="pixiedust-output-wrapper-3c8f4997" class="pixiedust-output-wrapper collapse in">
#
#       <div class="pixiedust-toolbar btn-group" role="group" style="margin-bottom:15px">
#
#
#           <a class="btn btn-small btn-default display-type-button" id="menu3c8f4997-tableView" title="Table.Next">
#             <i class="fa fa-table"></i>
#           </a>
#
#             <script>
#                 $('#menu3c8f4997-tableView').on('click',
#
#             function(){
#                 pixiedust.executeDisplay(
#                     {"prefix": "3c8f4997", "command": "display(Topmovies,cell_id='c1e40852e4924faf8215966b8fbd0b7d',nostore_pixiedust='true',handlerId='tableView',keyFields='title',orientation='horizontal',rowCount='100000',valueFields='rating_count',nostore_cw='1098',nostore_vh='656',org_params='nostore_pixiedust',nostore_bokeh='false',prefix='3c8f4997')", "entity": "Topmovies", "options": {"cell_id": "c1e40852e4924faf8215966b8fbd0b7d", "nostore_pixiedust": "true", "handlerId": "tableView", "keyFields": "title", "orientation": "horizontal", "rowCount": "100000", "valueFields": "rating_count", "nostore_cw": "1098", "nostore_vh": "656", "org_params": "nostore_pixiedust", "nostore_bokeh": "false", "prefix": "3c8f4997"}, "sniffers": ["{'nostore_bokeh':!!window.Bokeh}"], "avoidMetadata": true, "include_keys": ["filter"]},
#                     {'targetDivId': 'wrapperHTML3c8f4997' }
#                 );
#             }
#             )
#             </script>
#
#
#
#
#           <div class="btn-group btn-small display-type-button">
#
#             <a class="btn btn-small dropdown-toggle btn-default" data-toggle="dropdown" title="Chart">
#
#               <i class="fa fa-line-chart"></i>
#
#               <i class="fa fa-chevron-down"></i>
#             </a>
#             <div class="dropdown-menu" role="menu" style="white-space:nowrap">
#               <ul>
#
#                 <li id="menu3c8f4997-barChart">
#
#                   <i class="fa fa-bar-chart"></i>
#
#                   <span>Bar Chart</span>
#
#             <script>
#                 $('#menu3c8f4997-barChart').on('click',
#
#             function(){
#                 pixiedust.executeDisplay(
#                     {"prefix": "3c8f4997", "command": "display(Topmovies,cell_id='c1e40852e4924faf8215966b8fbd0b7d',nostore_pixiedust='true',handlerId='barChart',keyFields='title',orientation='horizontal',rowCount='100000',valueFields='rating_count',nostore_cw='1098',nostore_vh='656',org_params='nostore_pixiedust',nostore_bokeh='false',prefix='3c8f4997')", "entity": "Topmovies", "options": {"cell_id": "c1e40852e4924faf8215966b8fbd0b7d", "nostore_pixiedust": "true", "handlerId": "barChart", "keyFields": "title", "orientation": "horizontal", "rowCount": "100000", "valueFields": "rating_count", "nostore_cw": "1098", "nostore_vh": "656", "org_params": "nostore_pixiedust", "nostore_bokeh": "false", "prefix": "3c8f4997"}, "sniffers": ["{'nostore_bokeh':!!window.Bokeh}"], "avoidMetadata": true, "include_keys": ["filter"]},
#                     {'targetDivId': 'wrapperHTML3c8f4997' }
#                 );
#             }
#             )
#             </script>
#
#                 </li>
#
#                 <li id="menu3c8f4997-lineChart">
#
#                   <i class="fa fa-line-chart"></i>
#
#                   <span>Line Chart</span>
#
#             <script>
#                 $('#menu3c8f4997-lineChart').on('click',
#
#             function(){
#                 pixiedust.executeDisplay(
#                     {"prefix": "3c8f4997", "command": "display(Topmovies,cell_id='c1e40852e4924faf8215966b8fbd0b7d',nostore_pixiedust='true',handlerId='lineChart',keyFields='title',orientation='horizontal',rowCount='100000',valueFields='rating_count',nostore_cw='1098',nostore_vh='656',org_params='nostore_pixiedust',nostore_bokeh='false',prefix='3c8f4997')", "entity": "Topmovies", "options": {"cell_id": "c1e40852e4924faf8215966b8fbd0b7d", "nostore_pixiedust": "true", "handlerId": "lineChart", "keyFields": "title", "orientation": "horizontal", "rowCount": "100000", "valueFields": "rating_count", "nostore_cw": "1098", "nostore_vh": "656", "org_params": "nostore_pixiedust", "nostore_bokeh": "false", "prefix": "3c8f4997"}, "sniffers": ["{'nostore_bokeh':!!window.Bokeh}"], "avoidMetadata": true, "include_keys": ["filter"]},
#                     {'targetDivId': 'wrapperHTML3c8f4997' }
#                 );
#             }
#             )
#             </script>
#
#                 </li>
#
#                 <li id="menu3c8f4997-scatterPlot">
#
#                   <i class="fa fa-circle"></i>
#
#                   <span>Scatter Plot</span>
#
#             <script>
#                 $('#menu3c8f4997-scatterPlot').on('click',
#
#             function(){
#                 pixiedust.executeDisplay(
#                     {"prefix": "3c8f4997", "command": "display(Topmovies,cell_id='c1e40852e4924faf8215966b8fbd0b7d',nostore_pixiedust='true',handlerId='scatterPlot',keyFields='title',orientation='horizontal',rowCount='100000',valueFields='rating_count',nostore_cw='1098',nostore_vh='656',org_params='nostore_pixiedust',nostore_bokeh='false',prefix='3c8f4997')", "entity": "Topmovies", "options": {"cell_id": "c1e40852e4924faf8215966b8fbd0b7d", "nostore_pixiedust": "true", "handlerId": "scatterPlot", "keyFields": "title", "orientation": "horizontal", "rowCount": "100000", "valueFields": "rating_count", "nostore_cw": "1098", "nostore_vh": "656", "org_params": "nostore_pixiedust", "nostore_bokeh": "false", "prefix": "3c8f4997"}, "sniffers": ["{'nostore_bokeh':!!window.Bokeh}"], "avoidMetadata": true, "include_keys": ["filter"]},
#                     {'targetDivId': 'wrapperHTML3c8f4997' }
#                 );
#             }
#             )
#             </script>
#
#                 </li>
#
#                 <li id="menu3c8f4997-pieChart">
#
#                   <i class="fa fa-pie-chart"></i>
#
#                   <span>Pie Chart</span>
#
#             <script>
#                 $('#menu3c8f4997-pieChart').on('click',
#
#             function(){
#                 pixiedust.executeDisplay(
#                     {"prefix": "3c8f4997", "command": "display(Topmovies,cell_id='c1e40852e4924faf821596

# %% [markdown]
# ## Visualisation on the trend of movies produced in each year

# %%
Movie_Rating.select("Year")\
.groupby("Year").count().orderBy(desc("count")).show()
# Out:
# +----+-----+
# |Year|count|
# +----+-----+
# |2015| 2244|
# |2014| 2221|
# |2016| 2163|
# |2013| 2107|
# |2012| 1940|
# |2011| 1833|
# |2017| 1832|
# |2009| 1752|
# |2010| 1681|
# |2008| 1610|
# |2007| 1458|
# |2006| 1406|
# |2005| 1226|
# |2004| 1127|
# |2003| 1000|
# |2002|  996|
# |2001|  937|
# |2000|  907|
# |2018|  826|
# |1999|  788|
# +----+-----+
# only showing top 20 rows

# %%
Year_Count= Movie_Rating.select(Movie_Rating.Year).groupby(Movie_Rating.Year).count()

# %%
Year_Count.registerTempTable("yearwise")

# %%
Year_Wise_Count = sqlContext.\
sql("select Year, \
SUM(count) as Total \
 from yearwise group by Year order by Year")

# %%
Year_Wise_Count.show()
# Out:
# +----+-----+
# |Year|Total|
# +----+-----+
# |null|  499|
# |   6|    1|
# |1874|    1|
# |1878|    1|
# |1883|    1|
# |1887|    1|
# |1888|    4|
# |1890|    5|
# |1891|    6|
# |1892|    3|
# |1893|    1|
# |1894|   21|
# |1895|    8|
# |1896|   19|
# |1897|   11|
# |1898|   12|
# |1899|    6|
# |1900|   17|
# |1901|   13|
# |1902|    4|
# +----+-----+
# only showing top 20 rows

# %%
display(Year_Wise_Count)
# Out:
# <div class="pixiedust" pixiedust="{&quot;prefix&quot;: &quot;74dd41c3&quot;, &quot;command&quot;: &quot;display(Year_Wise_Count,cell_id=&apos;8a8acb637e5d4a5f84a611442e25d47c&apos;,nostore_pixiedust=&apos;true&apos;,handlerId=&apos;barChart&apos;,keyFields=&apos;Year&apos;,orientation=&apos;horizontal&apos;,valueFields=&apos;Total&apos;,nostore_cw=&apos;1098&apos;,nostore_vh=&apos;656&apos;,org_params=&apos;nostore_pixiedust&apos;,nostore_bokeh=&apos;false&apos;)&quot;, &quot;entity&quot;: &quot;Year_Wise_Count&quot;, &quot;options&quot;: {&quot;cell_id&quot;: &quot;8a8acb637e5d4a5f84a611442e25d47c&quot;, &quot;nostore_pixiedust&quot;: &quot;true&quot;, &quot;handlerId&quot;: &quot;barChart&quot;, &quot;keyFields&quot;: &quot;Year&quot;, &quot;orientation&quot;: &quot;horizontal&quot;, &quot;valueFields&quot;: &quot;Total&quot;, &quot;nostore_cw&quot;: &quot;1098&quot;, &quot;nostore_vh&quot;: &quot;656&quot;, &quot;org_params&quot;: &quot;nostore_pixiedust&quot;, &quot;nostore_bokeh&quot;: &quot;false&quot;}, &quot;sniffers&quot;: [&quot;{&apos;nostore_bokeh&apos;:!!window.Bokeh}&quot;], &quot;avoidMetadata&quot;: false, &quot;include_keys&quot;: [&quot;filter&quot;]}">
#
#   <button class="btn btn-default btn-sm expandButton" data-toggle="collapse"
#           data-target="#pixiedust-output-wrapper-74dd41c3" title="Expand/Collapse Pixiedust output">
#     <i class="fa"></i>
#   </button>
#
#
#   <div id="pixiedust-output-wrapper-74dd41c3" class="pixiedust-output-wrapper collapse in">
#
#       <div class="pixiedust-toolbar btn-group" role="group" style="margin-bottom:15px">
#
#
#           <a class="btn btn-small btn-default display-type-button" id="menu74dd41c3-tableView" title="Table.Next">
#             <i class="fa fa-table"></i>
#           </a>
#
#             <script>
#                 $('#menu74dd41c3-tableView').on('click',
#
#             function(){
#                 pixiedust.executeDisplay(
#                     {"prefix": "74dd41c3", "command": "display(Year_Wise_Count,cell_id='8a8acb637e5d4a5f84a611442e25d47c',nostore_pixiedust='true',handlerId='tableView',keyFields='Year',orientation='horizontal',valueFields='Total',nostore_cw='1098',nostore_vh='656',org_params='nostore_pixiedust',nostore_bokeh='false',prefix='74dd41c3')", "entity": "Year_Wise_Count", "options": {"cell_id": "8a8acb637e5d4a5f84a611442e25d47c", "nostore_pixiedust": "true", "handlerId": "tableView", "keyFields": "Year", "orientation": "horizontal", "valueFields": "Total", "nostore_cw": "1098", "nostore_vh": "656", "org_params": "nostore_pixiedust", "nostore_bokeh": "false", "prefix": "74dd41c3"}, "sniffers": ["{'nostore_bokeh':!!window.Bokeh}"], "avoidMetadata": true, "include_keys": ["filter"]},
#                     {'targetDivId': 'wrapperHTML74dd41c3' }
#                 );
#             }
#             )
#             </script>
#
#
#
#
#           <div class="btn-group btn-small display-type-button">
#
#             <a class="btn btn-small dropdown-toggle btn-default" data-toggle="dropdown" title="Chart">
#
#               <i class="fa fa-line-chart"></i>
#
#               <i class="fa fa-chevron-down"></i>
#             </a>
#             <div class="dropdown-menu" role="menu" style="white-space:nowrap">
#               <ul>
#
#                 <li id="menu74dd41c3-barChart">
#
#                   <i class="fa fa-bar-chart"></i>
#
#                   <span>Bar Chart</span>
#
#             <script>
#                 $('#menu74dd41c3-barChart').on('click',
#
#             function(){
#                 pixiedust.executeDisplay(
#                     {"prefix": "74dd41c3", "command": "display(Year_Wise_Count,cell_id='8a8acb637e5d4a5f84a611442e25d47c',nostore_pixiedust='true',handlerId='barChart',keyFields='Year',orientation='horizontal',valueFields='Total',nostore_cw='1098',nostore_vh='656',org_params='nostore_pixiedust',nostore_bokeh='false',prefix='74dd41c3')", "entity": "Year_Wise_Count", "options": {"cell_id": "8a8acb637e5d4a5f84a611442e25d47c", "nostore_pixiedust": "true", "handlerId": "barChart", "keyFields": "Year", "orientation": "horizontal", "valueFields": "Total", "nostore_cw": "1098", "nostore_vh": "656", "org_params": "nostore_pixiedust", "nostore_bokeh": "false", "prefix": "74dd41c3"}, "sniffers": ["{'nostore_bokeh':!!window.Bokeh}"], "avoidMetadata": true, "include_keys": ["filter"]},
#                     {'targetDivId': 'wrapperHTML74dd41c3' }
#                 );
#             }
#             )
#             </script>
#
#                 </li>
#
#                 <li id="menu74dd41c3-lineChart">
#
#                   <i class="fa fa-line-chart"></i>
#
#                   <span>Line Chart</span>
#
#             <script>
#                 $('#menu74dd41c3-lineChart').on('click',
#
#             function(){
#                 pixiedust.executeDisplay(
#                     {"prefix": "74dd41c3", "command": "display(Year_Wise_Count,cell_id='8a8acb637e5d4a5f84a611442e25d47c',nostore_pixiedust='true',handlerId='lineChart',keyFields='Year',orientation='horizontal',valueFields='Total',nostore_cw='1098',nostore_vh='656',org_params='nostore_pixiedust',nostore_bokeh='false',prefix='74dd41c3')", "entity": "Year_Wise_Count", "options": {"cell_id": "8a8acb637e5d4a5f84a611442e25d47c", "nostore_pixiedust": "true", "handlerId": "lineChart", "keyFields": "Year", "orientation": "horizontal", "valueFields": "Total", "nostore_cw": "1098", "nostore_vh": "656", "org_params": "nostore_pixiedust", "nostore_bokeh": "false", "prefix": "74dd41c3"}, "sniffers": ["{'nostore_bokeh':!!window.Bokeh}"], "avoidMetadata": true, "include_keys": ["filter"]},
#                     {'targetDivId': 'wrapperHTML74dd41c3' }
#                 );
#             }
#             )
#             </script>
#
#                 </li>
#
#                 <li id="menu74dd41c3-scatterPlot">
#
#                   <i class="fa fa-circle"></i>
#
#                   <span>Scatter Plot</span>
#
#             <script>
#                 $('#menu74dd41c3-scatterPlot').on('click',
#
#             function(){
#                 pixiedust.executeDisplay(
#                     {"prefix": "74dd41c3", "command": "display(Year_Wise_Count,cell_id='8a8acb637e5d4a5f84a611442e25d47c',nostore_pixiedust='true',handlerId='scatterPlot',keyFields='Year',orientation='horizontal',valueFields='Total',nostore_cw='1098',nostore_vh='656',org_params='nostore_pixiedust',nostore_bokeh='false',prefix='74dd41c3')", "entity": "Year_Wise_Count", "options": {"cell_id": "8a8acb637e5d4a5f84a611442e25d47c", "nostore_pixiedust": "true", "handlerId": "scatterPlot", "keyFields": "Year", "orientation": "horizontal", "valueFields": "Total", "nostore_cw": "1098", "nostore_vh": "656", "org_params": "nostore_pixiedust", "nostore_bokeh": "false", "prefix": "74dd41c3"}, "sniffers": ["{'nostore_bokeh':!!window.Bokeh}"], "avoidMetadata": true, "include_keys": ["filter"]},
#                     {'targetDivId': 'wrapperHTML74dd41c3' }
#                 );
#             }
#             )
#             </script>
#
#                 </li>
#
#                 <li id="menu74dd41c3-pieChart">
#
#                   <i class="fa fa-pie-chart"></i>
#
#                   <span>Pie Chart</span>
#
#             <script>
#                 $('#menu74dd41c3-pieChart').on('click',
#
#             function(){
#                 pixiedust.executeDisplay(
#                     {"prefix": "74dd41c3", "command": "display(Year_Wise_Count,cell_id='8a8acb637e5d4a5f84a611442e25d47c',nostore_pixiedust='true',handlerId='pieChart',keyFields='Year',orientation='horizontal',valueFields='Total',nostore_cw='1098',nostore_vh='656',org_params='nostore_pixiedust',nostore_bokeh='false',prefix='74dd41c3')", "entity": "Year

# %%
#Displaying the years with movie count more than 1000

display(Year_Wise_Count)
# Out:
# <div class="pixiedust" pixiedust="{&quot;prefix&quot;: &quot;01ed4b74&quot;, &quot;command&quot;: &quot;display(Year_Wise_Count,cell_id=&apos;e72d5e2b9aa34a9c82b4a6e05707a1f8&apos;,nostore_pixiedust=&apos;true&apos;,filter=&apos;{\&quot;field\&quot;: \&quot;Total\&quot;,\&quot;constraint\&quot;: \&quot;greater_than\&quot;,\&quot;value\&quot;: \&quot;1000\&quot;,\&quot;case_matter\&quot;: \&quot;False\&quot;,\&quot;regex\&quot;: \&quot;False\&quot;}&apos;,handlerId=&apos;barChart&apos;,keyFields=&apos;Year&apos;,logx=&apos;true&apos;,no_margin=&apos;true&apos;,rowCount=&apos;1000000&apos;,valueFields=&apos;Total&apos;,nostore_cw=&apos;1098&apos;,nostore_vh=&apos;656&apos;,org_params=&apos;nostore_pixiedust&apos;,nostore_bokeh=&apos;false&apos;)&quot;, &quot;entity&quot;: &quot;Year_Wise_Count&quot;, &quot;options&quot;: {&quot;cell_id&quot;: &quot;e72d5e2b9aa34a9c82b4a6e05707a1f8&quot;, &quot;nostore_pixiedust&quot;: &quot;true&quot;, &quot;filter&quot;: &quot;{\&quot;field\&quot;: \&quot;Total\&quot;,\&quot;constraint\&quot;: \&quot;greater_than\&quot;,\&quot;value\&quot;: \&quot;1000\&quot;,\&quot;case_matter\&quot;: \&quot;False\&quot;,\&quot;regex\&quot;: \&quot;False\&quot;}&quot;, &quot;handlerId&quot;: &quot;barChart&quot;, &quot;keyFields&quot;: &quot;Year&quot;, &quot;logx&quot;: &quot;true&quot;, &quot;no_margin&quot;: &quot;true&quot;, &quot;rowCount&quot;: &quot;1000000&quot;, &quot;valueFields&quot;: &quot;Total&quot;, &quot;nostore_cw&quot;: &quot;1098&quot;, &quot;nostore_vh&quot;: &quot;656&quot;, &quot;org_params&quot;: &quot;nostore_pixiedust&quot;, &quot;nostore_bokeh&quot;: &quot;false&quot;}, &quot;sniffers&quot;: [&quot;{&apos;nostore_bokeh&apos;:!!window.Bokeh}&quot;], &quot;avoidMetadata&quot;: false, &quot;include_keys&quot;: [&quot;filter&quot;]}">
#
#   <button class="btn btn-default btn-sm expandButton" data-toggle="collapse"
#           data-target="#pixiedust-output-wrapper-01ed4b74" title="Expand/Collapse Pixiedust output">
#     <i class="fa"></i>
#   </button>
#
#
#   <div id="pixiedust-output-wrapper-01ed4b74" class="pixiedust-output-wrapper collapse in">
#
#       <div class="pixiedust-toolbar btn-group" role="group" style="margin-bottom:15px">
#
#
#           <a class="btn btn-small btn-default display-type-button" id="menu01ed4b74-tableView" title="Table.Next">
#             <i class="fa fa-table"></i>
#           </a>
#
#             <script>
#                 $('#menu01ed4b74-tableView').on('click',
#
#             function(){
#                 pixiedust.executeDisplay(
#                     {"prefix": "01ed4b74", "command": "display(Year_Wise_Count,cell_id='e72d5e2b9aa34a9c82b4a6e05707a1f8',nostore_pixiedust='true',filter='{\"field\": \"Total\",\"constraint\": \"greater_than\",\"value\": \"1000\",\"case_matter\": \"False\",\"regex\": \"False\"}',handlerId='tableView',keyFields='Year',logx='true',no_margin='true',rowCount='1000000',valueFields='Total',nostore_cw='1098',nostore_vh='656',org_params='nostore_pixiedust',nostore_bokeh='false',prefix='01ed4b74')", "entity": "Year_Wise_Count", "options": {"cell_id": "e72d5e2b9aa34a9c82b4a6e05707a1f8", "nostore_pixiedust": "true", "filter": "{\"field\": \"Total\",\"constraint\": \"greater_than\",\"value\": \"1000\",\"case_matter\": \"False\",\"regex\": \"False\"}", "handlerId": "tableView", "keyFields": "Year", "logx": "true", "no_margin": "true", "rowCount": "1000000", "valueFields": "Total", "nostore_cw": "1098", "nostore_vh": "656", "org_params": "nostore_pixiedust", "nostore_bokeh": "false", "prefix": "01ed4b74"}, "sniffers": ["{'nostore_bokeh':!!window.Bokeh}"], "avoidMetadata": true, "include_keys": ["filter"]},
#                     {'targetDivId': 'wrapperHTML01ed4b74' }
#                 );
#             }
#             )
#             </script>
#
#
#
#
#           <div class="btn-group btn-small display-type-button">
#
#             <a class="btn btn-small dropdown-toggle btn-default" data-toggle="dropdown" title="Chart">
#
#               <i class="fa fa-line-chart"></i>
#
#               <i class="fa fa-chevron-down"></i>
#             </a>
#             <div class="dropdown-menu" role="menu" style="white-space:nowrap">
#               <ul>
#
#                 <li id="menu01ed4b74-barChart">
#
#                   <i class="fa fa-bar-chart"></i>
#
#                   <span>Bar Chart</span>
#
#             <script>
#                 $('#menu01ed4b74-barChart').on('click',
#
#             function(){
#                 pixiedust.executeDisplay(
#                     {"prefix": "01ed4b74", "command": "display(Year_Wise_Count,cell_id='e72d5e2b9aa34a9c82b4a6e05707a1f8',nostore_pixiedust='true',filter='{\"field\": \"Total\",\"constraint\": \"greater_than\",\"value\": \"1000\",\"case_matter\": \"False\",\"regex\": \"False\"}',handlerId='barChart',keyFields='Year',logx='true',no_margin='true',rowCount='1000000',valueFields='Total',nostore_cw='1098',nostore_vh='656',org_params='nostore_pixiedust',nostore_bokeh='false',prefix='01ed4b74')", "entity": "Year_Wise_Count", "options": {"cell_id": "e72d5e2b9aa34a9c82b4a6e05707a1f8", "nostore_pixiedust": "true", "filter": "{\"field\": \"Total\",\"constraint\": \"greater_than\",\"value\": \"1000\",\"case_matter\": \"False\",\"regex\": \"False\"}", "handlerId": "barChart", "keyFields": "Year", "logx": "true", "no_margin": "true", "rowCount": "1000000", "valueFields": "Total", "nostore_cw": "1098", "nostore_vh": "656", "org_params": "nostore_pixiedust", "nostore_bokeh": "false", "prefix": "01ed4b74"}, "sniffers": ["{'nostore_bokeh':!!window.Bokeh}"], "avoidMetadata": true, "include_keys": ["filter"]},
#                     {'targetDivId': 'wrapperHTML01ed4b74' }
#                 );
#             }
#             )
#             </script>
#
#                 </li>
#
#                 <li id="menu01ed4b74-lineChart">
#
#                   <i class="fa fa-line-chart"></i>
#
#                   <span>Line Chart</span>
#
#             <script>
#                 $('#menu01ed4b74-lineChart').on('click',
#
#             function(){
#                 pixiedust.executeDisplay(
#                     {"prefix": "01ed4b74", "command": "display(Year_Wise_Count,cell_id='e72d5e2b9aa34a9c82b4a6e05707a1f8',nostore_pixiedust='true',filter='{\"field\": \"Total\",\"constraint\": \"greater_than\",\"value\": \"1000\",\"case_matter\": \"False\",\"regex\": \"False\"}',handlerId='lineChart',keyFields='Year',logx='true',no_margin='true',rowCount='1000000',valueFields='Total',nostore_cw='1098',nostore_vh='656',org_params='nostore_pixiedust',nostore_bokeh='false',prefix='01ed4b74')", "entity": "Year_Wise_Count", "options": {"cell_id": "e72d5e2b9aa34a9c82b4a6e05707a1f8", "nostore_pixiedust": "true", "filter": "{\"field\": \"Total\",\"constraint\": \"greater_than\",\"value\": \"1000\",\"case_matter\": \"False\",\"regex\": \"False\"}", "handlerId": "lineChart", "keyFields": "Year", "logx": "true", "no_margin": "true", "rowCount": "1000000", "valueFields": "Total", "nostore_cw": "1098", "nostore_vh": "656", "org_params": "nostore_pixiedust", "nostore_bokeh": "false", "prefix": "01ed4b74"}, "sniffers": ["{'nostore_bokeh':!!window.Bokeh}"], "avoidMetadata": true, "include_keys": ["filter"]},
#                     {'targetDivId': 'wrapperHTML01ed4b74' }
#                 );
#             }
#             )
#             </script>
#
#                 </li>
#
#                 <li id="menu01ed4b74-scatterPlot">
#
#                   <i class="fa fa-circle"></i>
#
#                   <span>Scatter Plot</span>
#
#             <script>
#                 $('#menu01ed4b74-scatterPlot').on('click',
#
#             function(){
#                 pixiedust.executeDisplay(
#                     {"prefix": "01ed4b74", "command": "display(Year_Wise_Count,cell_id

# %%
#Displaying the years with movie count less than 10

display(Year_Wise_Count)
# Out:
# <div class="pixiedust" pixiedust="{&quot;prefix&quot;: &quot;2bd7e5b1&quot;, &quot;command&quot;: &quot;display(Year_Wise_Count,cell_id=&apos;e81b1bbb6255481497ca26ccd0a3cea7&apos;,nostore_pixiedust=&apos;true&apos;,aggregation=&apos;SUM&apos;,filter=&apos;{\&quot;field\&quot;: \&quot;Total\&quot;,\&quot;constraint\&quot;: \&quot;less_than\&quot;,\&quot;value\&quot;: \&quot;10\&quot;,\&quot;case_matter\&quot;: \&quot;False\&quot;,\&quot;regex\&quot;: \&quot;False\&quot;}&apos;,handlerId=&apos;barChart&apos;,keyFields=&apos;Year&apos;,no_margin=&apos;true&apos;,rowCount=&apos;9982&apos;,valueFields=&apos;Total&apos;,nostore_cw=&apos;1098&apos;,nostore_vh=&apos;656&apos;,org_params=&apos;nostore_pixiedust&apos;,nostore_bokeh=&apos;false&apos;)&quot;, &quot;entity&quot;: &quot;Year_Wise_Count&quot;, &quot;options&quot;: {&quot;cell_id&quot;: &quot;e81b1bbb6255481497ca26ccd0a3cea7&quot;, &quot;nostore_pixiedust&quot;: &quot;true&quot;, &quot;aggregation&quot;: &quot;SUM&quot;, &quot;filter&quot;: &quot;{\&quot;field\&quot;: \&quot;Total\&quot;,\&quot;constraint\&quot;: \&quot;less_than\&quot;,\&quot;value\&quot;: \&quot;10\&quot;,\&quot;case_matter\&quot;: \&quot;False\&quot;,\&quot;regex\&quot;: \&quot;False\&quot;}&quot;, &quot;handlerId&quot;: &quot;barChart&quot;, &quot;keyFields&quot;: &quot;Year&quot;, &quot;no_margin&quot;: &quot;true&quot;, &quot;rowCount&quot;: &quot;9982&quot;, &quot;valueFields&quot;: &quot;Total&quot;, &quot;nostore_cw&quot;: &quot;1098&quot;, &quot;nostore_vh&quot;: &quot;656&quot;, &quot;org_params&quot;: &quot;nostore_pixiedust&quot;, &quot;nostore_bokeh&quot;: &quot;false&quot;}, &quot;sniffers&quot;: [&quot;{&apos;nostore_bokeh&apos;:!!window.Bokeh}&quot;], &quot;avoidMetadata&quot;: false, &quot;include_keys&quot;: [&quot;filter&quot;]}">
#
#   <button class="btn btn-default btn-sm expandButton" data-toggle="collapse"
#           data-target="#pixiedust-output-wrapper-2bd7e5b1" title="Expand/Collapse Pixiedust output">
#     <i class="fa"></i>
#   </button>
#
#
#   <div id="pixiedust-output-wrapper-2bd7e5b1" class="pixiedust-output-wrapper collapse in">
#
#       <div class="pixiedust-toolbar btn-group" role="group" style="margin-bottom:15px">
#
#
#           <a class="btn btn-small btn-default display-type-button" id="menu2bd7e5b1-tableView" title="Table.Next">
#             <i class="fa fa-table"></i>
#           </a>
#
#             <script>
#                 $('#menu2bd7e5b1-tableView').on('click',
#
#             function(){
#                 pixiedust.executeDisplay(
#                     {"prefix": "2bd7e5b1", "command": "display(Year_Wise_Count,cell_id='e81b1bbb6255481497ca26ccd0a3cea7',nostore_pixiedust='true',aggregation='SUM',filter='{\"field\": \"Total\",\"constraint\": \"less_than\",\"value\": \"10\",\"case_matter\": \"False\",\"regex\": \"False\"}',handlerId='tableView',keyFields='Year',no_margin='true',rowCount='9982',valueFields='Total',nostore_cw='1098',nostore_vh='656',org_params='nostore_pixiedust',nostore_bokeh='false',prefix='2bd7e5b1')", "entity": "Year_Wise_Count", "options": {"cell_id": "e81b1bbb6255481497ca26ccd0a3cea7", "nostore_pixiedust": "true", "aggregation": "SUM", "filter": "{\"field\": \"Total\",\"constraint\": \"less_than\",\"value\": \"10\",\"case_matter\": \"False\",\"regex\": \"False\"}", "handlerId": "tableView", "keyFields": "Year", "no_margin": "true", "rowCount": "9982", "valueFields": "Total", "nostore_cw": "1098", "nostore_vh": "656", "org_params": "nostore_pixiedust", "nostore_bokeh": "false", "prefix": "2bd7e5b1"}, "sniffers": ["{'nostore_bokeh':!!window.Bokeh}"], "avoidMetadata": true, "include_keys": ["filter"]},
#                     {'targetDivId': 'wrapperHTML2bd7e5b1' }
#                 );
#             }
#             )
#             </script>
#
#
#
#
#           <div class="btn-group btn-small display-type-button">
#
#             <a class="btn btn-small dropdown-toggle btn-default" data-toggle="dropdown" title="Chart">
#
#               <i class="fa fa-line-chart"></i>
#
#               <i class="fa fa-chevron-down"></i>
#             </a>
#             <div class="dropdown-menu" role="menu" style="white-space:nowrap">
#               <ul>
#
#                 <li id="menu2bd7e5b1-barChart">
#
#                   <i class="fa fa-bar-chart"></i>
#
#                   <span>Bar Chart</span>
#
#             <script>
#                 $('#menu2bd7e5b1-barChart').on('click',
#
#             function(){
#                 pixiedust.executeDisplay(
#                     {"prefix": "2bd7e5b1", "command": "display(Year_Wise_Count,cell_id='e81b1bbb6255481497ca26ccd0a3cea7',nostore_pixiedust='true',aggregation='SUM',filter='{\"field\": \"Total\",\"constraint\": \"less_than\",\"value\": \"10\",\"case_matter\": \"False\",\"regex\": \"False\"}',handlerId='barChart',keyFields='Year',no_margin='true',rowCount='9982',valueFields='Total',nostore_cw='1098',nostore_vh='656',org_params='nostore_pixiedust',nostore_bokeh='false',prefix='2bd7e5b1')", "entity": "Year_Wise_Count", "options": {"cell_id": "e81b1bbb6255481497ca26ccd0a3cea7", "nostore_pixiedust": "true", "aggregation": "SUM", "filter": "{\"field\": \"Total\",\"constraint\": \"less_than\",\"value\": \"10\",\"case_matter\": \"False\",\"regex\": \"False\"}", "handlerId": "barChart", "keyFields": "Year", "no_margin": "true", "rowCount": "9982", "valueFields": "Total", "nostore_cw": "1098", "nostore_vh": "656", "org_params": "nostore_pixiedust", "nostore_bokeh": "false", "prefix": "2bd7e5b1"}, "sniffers": ["{'nostore_bokeh':!!window.Bokeh}"], "avoidMetadata": true, "include_keys": ["filter"]},
#                     {'targetDivId': 'wrapperHTML2bd7e5b1' }
#                 );
#             }
#             )
#             </script>
#
#                 </li>
#
#                 <li id="menu2bd7e5b1-lineChart">
#
#                   <i class="fa fa-line-chart"></i>
#
#                   <span>Line Chart</span>
#
#             <script>
#                 $('#menu2bd7e5b1-lineChart').on('click',
#
#             function(){
#                 pixiedust.executeDisplay(
#                     {"prefix": "2bd7e5b1", "command": "display(Year_Wise_Count,cell_id='e81b1bbb6255481497ca26ccd0a3cea7',nostore_pixiedust='true',aggregation='SUM',filter='{\"field\": \"Total\",\"constraint\": \"less_than\",\"value\": \"10\",\"case_matter\": \"False\",\"regex\": \"False\"}',handlerId='lineChart',keyFields='Year',no_margin='true',rowCount='9982',valueFields='Total',nostore_cw='1098',nostore_vh='656',org_params='nostore_pixiedust',nostore_bokeh='false',prefix='2bd7e5b1')", "entity": "Year_Wise_Count", "options": {"cell_id": "e81b1bbb6255481497ca26ccd0a3cea7", "nostore_pixiedust": "true", "aggregation": "SUM", "filter": "{\"field\": \"Total\",\"constraint\": \"less_than\",\"value\": \"10\",\"case_matter\": \"False\",\"regex\": \"False\"}", "handlerId": "lineChart", "keyFields": "Year", "no_margin": "true", "rowCount": "9982", "valueFields": "Total", "nostore_cw": "1098", "nostore_vh": "656", "org_params": "nostore_pixiedust", "nostore_bokeh": "false", "prefix": "2bd7e5b1"}, "sniffers": ["{'nostore_bokeh':!!window.Bokeh}"], "avoidMetadata": true, "include_keys": ["filter"]},
#                     {'targetDivId': 'wrapperHTML2bd7e5b1' }
#                 );
#             }
#             )
#             </script>
#
#                 </li>
#
#                 <li id="menu2bd7e5b1-scatterPlot">
#
#                   <i class="fa fa-circle"></i>
#
#                   <span>Scatter Plot</span>
#
#             <script>
#                 $('#menu2bd7e5b1-scatterPlot').on('click',
#
#             function(){
#                 pixiedust.executeDisplay(
#                     {"prefix": "2bd7e5b1", "command": "display(Year_Wise_Count,cell_id='e81b1bbb625548

# %% [markdown]
# ## Comparision of Genre combination between 20th Century and 21st Century

# %%
Nintees_Movies=Movie_Rating.registerTempTable("Nintees_Movies")

# %%
#extracting movies which is releases before 2000
Nintees_Movies=sqlContext.\
sql("select * \
from Nintees_Movies \
where Year < 2000 and Year >1900 \
order by rating_count")

# %%
Nintees_Movies.show()
# Out:
# +-------+--------------------+----+--------------------+----------+------------+
# |movieId|               title|Year|              genres|avg_rating|rating_count|
# +-------+--------------------+----+--------------------+----------+------------+
# | 120749|Mexican Spitfire ...|1940|              Comedy|       2.0|           1|
# |  90493|War of the Robots...|1978|Action|Adventure|...|       2.5|           1|
# | 113812|        Bullet Scars|1942|         Crime|Drama|       2.5|           1|
# |  96706|   Straight Shooting|1917|             Western|       4.0|           1|
# | 112251|            Snapshot|1979|Drama|Horror|Thri...|       1.0|           1|
# | 127092|The Kiss of Her F...|1968|     Horror|Thriller|       1.0|           1|
# | 168902| Behind Green Lights|1946|               Crime|       3.5|           1|
# | 134873|              Ginger|1971|  Action|Crime|Drama|       2.0|           1|
# |  93905|    The Gamma People|1956|       Horror|Sci-Fi|       2.0|           1|
# | 126309|     Vessel of Wrath|1938|               Drama|       2.5|           1|
# | 176233|The Imperceptable...|1904|  (no genres listed)|       2.0|           1|
# | 181693|      The Red Ribbon|1999|  (no genres listed)|       3.5|           1|
# | 181737|    Martians Go Home|1990|       Comedy|Sci-Fi|       3.0|           1|
# | 185115|The City and the ...|1985|               Drama|       3.5|           1|
# | 185913|Shadows in the Storm|1988|  (no genres listed)|       2.5|           1|
# | 188287|The Brave Tin Sol...|1976|Animation|Childre...|       2.0|           1|
# | 193165|    The Great Moment|1944|        Comedy|Drama|       3.0|           1|
# | 159433|     Two Timid Souls|1928|              Comedy|       3.5|           1|
# | 119641|        Face of Fire|1959|               Drama|       3.5|           1|
# | 161538|         Broadminded|1931|              Comedy|       1.5|           1|
# +-------+--------------------+----+--------------------+----------+------------+
# only showing top 20 rows

# %%
display(Nintees_Movies)
# Out:
# <div class="pixiedust" pixiedust="{&quot;prefix&quot;: &quot;93612289&quot;, &quot;command&quot;: &quot;display(Nintees_Movies,cell_id=&apos;0e562e893b6540278f27272a10b599ee&apos;,nostore_pixiedust=&apos;true&apos;,filter=&apos;{}&apos;,handlerId=&apos;pieChart&apos;,keyFields=&apos;genres&apos;,mpld3=&apos;false&apos;,no_margin=&apos;true&apos;,orientation=&apos;vertical&apos;,rowCount=&apos;9999&apos;,sortby=&apos;Values DESC&apos;,valueFields=&apos;avg_rating&apos;,nostore_cw=&apos;1098&apos;,nostore_vh=&apos;656&apos;,org_params=&apos;nostore_pixiedust&apos;,nostore_bokeh=&apos;false&apos;)&quot;, &quot;entity&quot;: &quot;Nintees_Movies&quot;, &quot;options&quot;: {&quot;cell_id&quot;: &quot;0e562e893b6540278f27272a10b599ee&quot;, &quot;nostore_pixiedust&quot;: &quot;true&quot;, &quot;filter&quot;: &quot;{}&quot;, &quot;handlerId&quot;: &quot;pieChart&quot;, &quot;keyFields&quot;: &quot;genres&quot;, &quot;mpld3&quot;: &quot;false&quot;, &quot;no_margin&quot;: &quot;true&quot;, &quot;orientation&quot;: &quot;vertical&quot;, &quot;rowCount&quot;: &quot;9999&quot;, &quot;sortby&quot;: &quot;Values DESC&quot;, &quot;valueFields&quot;: &quot;avg_rating&quot;, &quot;nostore_cw&quot;: &quot;1098&quot;, &quot;nostore_vh&quot;: &quot;656&quot;, &quot;org_params&quot;: &quot;nostore_pixiedust&quot;, &quot;nostore_bokeh&quot;: &quot;false&quot;}, &quot;sniffers&quot;: [&quot;{&apos;nostore_bokeh&apos;:!!window.Bokeh}&quot;], &quot;avoidMetadata&quot;: false, &quot;include_keys&quot;: [&quot;filter&quot;]}">
#
#   <button class="btn btn-default btn-sm expandButton" data-toggle="collapse"
#           data-target="#pixiedust-output-wrapper-93612289" title="Expand/Collapse Pixiedust output">
#     <i class="fa"></i>
#   </button>
#
#
#   <div id="pixiedust-output-wrapper-93612289" class="pixiedust-output-wrapper collapse in">
#
#       <div class="pixiedust-toolbar btn-group" role="group" style="margin-bottom:15px">
#
#
#           <a class="btn btn-small btn-default display-type-button" id="menu93612289-tableView" title="Table.Next">
#             <i class="fa fa-table"></i>
#           </a>
#
#             <script>
#                 $('#menu93612289-tableView').on('click',
#
#             function(){
#                 pixiedust.executeDisplay(
#                     {"prefix": "93612289", "command": "display(Nintees_Movies,cell_id='0e562e893b6540278f27272a10b599ee',nostore_pixiedust='true',filter='{}',handlerId='tableView',keyFields='genres',mpld3='false',no_margin='true',orientation='vertical',rowCount='9999',sortby='Values DESC',valueFields='avg_rating',nostore_cw='1098',nostore_vh='656',org_params='nostore_pixiedust',nostore_bokeh='false',prefix='93612289')", "entity": "Nintees_Movies", "options": {"cell_id": "0e562e893b6540278f27272a10b599ee", "nostore_pixiedust": "true", "filter": "{}", "handlerId": "tableView", "keyFields": "genres", "mpld3": "false", "no_margin": "true", "orientation": "vertical", "rowCount": "9999", "sortby": "Values DESC", "valueFields": "avg_rating", "nostore_cw": "1098", "nostore_vh": "656", "org_params": "nostore_pixiedust", "nostore_bokeh": "false", "prefix": "93612289"}, "sniffers": ["{'nostore_bokeh':!!window.Bokeh}"], "avoidMetadata": true, "include_keys": ["filter"]},
#                     {'targetDivId': 'wrapperHTML93612289' }
#                 );
#             }
#             )
#             </script>
#
#
#
#
#           <div class="btn-group btn-small display-type-button">
#
#             <a class="btn btn-small dropdown-toggle btn-default" data-toggle="dropdown" title="Chart">
#
#               <i class="fa fa-line-chart"></i>
#
#               <i class="fa fa-chevron-down"></i>
#             </a>
#             <div class="dropdown-menu" role="menu" style="white-space:nowrap">
#               <ul>
#
#                 <li id="menu93612289-barChart">
#
#                   <i class="fa fa-bar-chart"></i>
#
#                   <span>Bar Chart</span>
#
#             <script>
#                 $('#menu93612289-barChart').on('click',
#
#             function(){
#                 pixiedust.executeDisplay(
#                     {"prefix": "93612289", "command": "display(Nintees_Movies,cell_id='0e562e893b6540278f27272a10b599ee',nostore_pixiedust='true',filter='{}',handlerId='barChart',keyFields='genres',mpld3='false',no_margin='true',orientation='vertical',rowCount='9999',sortby='Values DESC',valueFields='avg_rating',nostore_cw='1098',nostore_vh='656',org_params='nostore_pixiedust',nostore_bokeh='false',prefix='93612289')", "entity": "Nintees_Movies", "options": {"cell_id": "0e562e893b6540278f27272a10b599ee", "nostore_pixiedust": "true", "filter": "{}", "handlerId": "barChart", "keyFields": "genres", "mpld3": "false", "no_margin": "true", "orientation": "vertical", "rowCount": "9999", "sortby": "Values DESC", "valueFields": "avg_rating", "nostore_cw": "1098", "nostore_vh": "656", "org_params": "nostore_pixiedust", "nostore_bokeh": "false", "prefix": "93612289"}, "sniffers": ["{'nostore_bokeh':!!window.Bokeh}"], "avoidMetadata": true, "include_keys": ["filter"]},
#                     {'targetDivId': 'wrapperHTML93612289' }
#                 );
#             }
#             )
#             </script>
#
#                 </li>
#
#                 <li id="menu93612289-lineChart">
#
#                   <i class="fa fa-line-chart"></i>
#
#                   <span>Line Chart</span>
#
#             <script>
#                 $('#menu93612289-lineChart').on('click',
#
#             function(){
#                 pixiedust.executeDisplay(
#                     {"prefix": "93612289", "command": "display(Nintees_Movies,cell_id='0e562e893b6540278f27272a10b599ee',nostore_pixiedust='true',filter='{}',handlerId='lineChart',keyFields='genres',mpld3='false',no_margin='true',orientation='vertical',rowCount='9999',sortby='Values DESC',valueFields='avg_rating',nostore_cw='1098',nostore_vh='656',org_params='nostore_pixiedust',nostore_bokeh='false',prefix='93612289')", "entity": "Nintees_Movies", "options": {"cell_id": "0e562e893b6540278f27272a10b599ee", "nostore_pixiedust": "true", "filter": "{}", "handlerId": "lineChart", "keyFields": "genres", "mpld3": "false", "no_margin": "true", "orientation": "vertical", "rowCount": "9999", "sortby": "Values DESC", "valueFields": "avg_rating", "nostore_cw": "1098", "nostore_vh": "656", "org_params": "nostore_pixiedust", "nostore_bokeh": "false", "prefix": "93612289"}, "sniffers": ["{'nostore_bokeh':!!window.Bokeh}"], "avoidMetadata": true, "include_keys": ["filter"]},
#                     {'targetDivId': 'wrapperHTML93612289' }
#                 );
#             }
#             )
#             </script>
#
#                 </li>
#
#                 <li id="menu93612289-scatterPlot">
#
#                   <i class="fa fa-circle"></i>
#
#                   <span>Scatter Plot</span>
#
#             <script>
#                 $('#menu93612289-scatterPlot').on('click',
#
#             function(){
#                 pixiedust.executeDisplay(
#                     {"prefix": "93612289", "command": "display(Nintees_Movies,cell_id='0e562e893b6540278f27272a10b599ee',nostore_pixiedust='true',filter='{}',handlerId='scatterPlot',keyFields='genres',mpld3='false',no_margin='true',orientation='vertical',rowCount='9999',sortby='Values DESC',valueFields='avg_rating',nostore_cw='1098',nostore_vh='656',org_params='nostore_pixiedust',nostore_bokeh='false',prefix='93612289')", "entity": "Nintees_Movies", "options": {"cell_id": "0e562e893b6540278f27272a10b599ee", "nostore_pixiedust": "true", "filter": "{}", "handlerId": "scatterPlot", "keyFields": "genres", "mpld3": "false", "no_margin": "true", "orientation": "vertical", "rowCount": "9999", "sortby": "Values DESC", "valueFields": "avg_rating", "nostore_cw": "1098",

# %%
Two_Thousands_Movies=Movie_Rating.registerTempTable("Two_Thousands_Movies")

# %%
#extracting movies which is releases after 2000
Two_Thousands_Movies=sqlContext.\
sql("select * \
from Two_Thousands_Movies \
where Year > 1999  \
order by rating_count")

# %%
Two_Thousands_Movies.show()
# Out:
# +-------+--------------------+----+--------------------+----------+------------+
# |movieId|               title|Year|              genres|avg_rating|rating_count|
# +-------+--------------------+----+--------------------+----------+------------+
# |  89537| Unlikely Weapon, An|2008|         Documentary|       3.5|           1|
# | 121763|Without Lying Dow...|2000|         Documentary|       3.0|           1|
# | 136924|Tekken: Kazuya's ...|2014|              Action|       2.5|           1|
# | 165495|            Ladrones|2015|        Comedy|Crime|       2.5|           1|
# | 163046|            Hattrick|2007|  (no genres listed)|       3.0|           1|
# | 145038|            Devotion|2003|               Drama|       4.0|           1|
# | 148324|              Reaper|2000|Horror|Mystery|Th...|       1.5|           1|
# | 149764|The Art of Seduction|2005|Comedy|Drama|Romance|       1.5|           1|
# | 154202|      Trench of Hope|2003|               Drama|       2.0|           1|
# | 162260|     Deuce of Spades|2010|Drama|Mystery|Thr...|       4.0|           1|
# | 165829|           Penis Boy|2015|        Comedy|Drama|       3.5|           1|
# | 171723|               Wushu|2008|        Action|Drama|       2.5|           1|
# | 174229|        Entre Bateas|2002|        Action|Drama|       3.5|           1|
# | 181399|         Little Rose|2010|       Drama|Romance|       3.5|           1|
# | 182945| Mission Pays Basque|2017|              Comedy|       2.5|           1|
# | 183275|             Jacked$|2004|  (no genres listed)|       5.0|           1|
# | 184483|  Particles of Truth|2003|  (no genres listed)|       4.5|           1|
# | 187525|2016 Oscar Nomina...|2016|  (no genres listed)|       2.5|           1|
# | 187693|Iron Maiden: Deat...|2006|  (no genres listed)|       4.0|           1|
# | 189903|         '63 Boycott|2016|         Documentary|       4.5|           1|
# +-------+--------------------+----+--------------------+----------+------------+
# only showing top 20 rows

# %%
display(Two_Thousands_Movies)
# Out:
# <div class="pixiedust" pixiedust="{&quot;prefix&quot;: &quot;05fcff58&quot;, &quot;command&quot;: &quot;display(Two_Thousands_Movies,cell_id=&apos;064dce5964604a988383ef3257a3f235&apos;,nostore_pixiedust=&apos;true&apos;,aggregation=&apos;SUM&apos;,handlerId=&apos;pieChart&apos;,keyFields=&apos;genres&apos;,rowCount=&apos;10000&apos;,valueFields=&apos;avg_rating&apos;,nostore_cw=&apos;1098&apos;,nostore_vh=&apos;656&apos;,org_params=&apos;nostore_pixiedust&apos;,nostore_bokeh=&apos;false&apos;)&quot;, &quot;entity&quot;: &quot;Two_Thousands_Movies&quot;, &quot;options&quot;: {&quot;cell_id&quot;: &quot;064dce5964604a988383ef3257a3f235&quot;, &quot;nostore_pixiedust&quot;: &quot;true&quot;, &quot;aggregation&quot;: &quot;SUM&quot;, &quot;handlerId&quot;: &quot;pieChart&quot;, &quot;keyFields&quot;: &quot;genres&quot;, &quot;rowCount&quot;: &quot;10000&quot;, &quot;valueFields&quot;: &quot;avg_rating&quot;, &quot;nostore_cw&quot;: &quot;1098&quot;, &quot;nostore_vh&quot;: &quot;656&quot;, &quot;org_params&quot;: &quot;nostore_pixiedust&quot;, &quot;nostore_bokeh&quot;: &quot;false&quot;}, &quot;sniffers&quot;: [&quot;{&apos;nostore_bokeh&apos;:!!window.Bokeh}&quot;], &quot;avoidMetadata&quot;: false, &quot;include_keys&quot;: [&quot;filter&quot;]}">
#
#   <button class="btn btn-default btn-sm expandButton" data-toggle="collapse"
#           data-target="#pixiedust-output-wrapper-05fcff58" title="Expand/Collapse Pixiedust output">
#     <i class="fa"></i>
#   </button>
#
#
#   <div id="pixiedust-output-wrapper-05fcff58" class="pixiedust-output-wrapper collapse in">
#
#       <div class="pixiedust-toolbar btn-group" role="group" style="margin-bottom:15px">
#
#
#           <a class="btn btn-small btn-default display-type-button" id="menu05fcff58-tableView" title="Table.Next">
#             <i class="fa fa-table"></i>
#           </a>
#
#             <script>
#                 $('#menu05fcff58-tableView').on('click',
#
#             function(){
#                 pixiedust.executeDisplay(
#                     {"prefix": "05fcff58", "command": "display(Two_Thousands_Movies,cell_id='064dce5964604a988383ef3257a3f235',nostore_pixiedust='true',aggregation='SUM',handlerId='tableView',keyFields='genres',rowCount='10000',valueFields='avg_rating',nostore_cw='1098',nostore_vh='656',org_params='nostore_pixiedust',nostore_bokeh='false',prefix='05fcff58')", "entity": "Two_Thousands_Movies", "options": {"cell_id": "064dce5964604a988383ef3257a3f235", "nostore_pixiedust": "true", "aggregation": "SUM", "handlerId": "tableView", "keyFields": "genres", "rowCount": "10000", "valueFields": "avg_rating", "nostore_cw": "1098", "nostore_vh": "656", "org_params": "nostore_pixiedust", "nostore_bokeh": "false", "prefix": "05fcff58"}, "sniffers": ["{'nostore_bokeh':!!window.Bokeh}"], "avoidMetadata": true, "include_keys": ["filter"]},
#                     {'targetDivId': 'wrapperHTML05fcff58' }
#                 );
#             }
#             )
#             </script>
#
#
#
#
#           <div class="btn-group btn-small display-type-button">
#
#             <a class="btn btn-small dropdown-toggle btn-default" data-toggle="dropdown" title="Chart">
#
#               <i class="fa fa-line-chart"></i>
#
#               <i class="fa fa-chevron-down"></i>
#             </a>
#             <div class="dropdown-menu" role="menu" style="white-space:nowrap">
#               <ul>
#
#                 <li id="menu05fcff58-barChart">
#
#                   <i class="fa fa-bar-chart"></i>
#
#                   <span>Bar Chart</span>
#
#             <script>
#                 $('#menu05fcff58-barChart').on('click',
#
#             function(){
#                 pixiedust.executeDisplay(
#                     {"prefix": "05fcff58", "command": "display(Two_Thousands_Movies,cell_id='064dce5964604a988383ef3257a3f235',nostore_pixiedust='true',aggregation='SUM',handlerId='barChart',keyFields='genres',rowCount='10000',valueFields='avg_rating',nostore_cw='1098',nostore_vh='656',org_params='nostore_pixiedust',nostore_bokeh='false',prefix='05fcff58')", "entity": "Two_Thousands_Movies", "options": {"cell_id": "064dce5964604a988383ef3257a3f235", "nostore_pixiedust": "true", "aggregation": "SUM", "handlerId": "barChart", "keyFields": "genres", "rowCount": "10000", "valueFields": "avg_rating", "nostore_cw": "1098", "nostore_vh": "656", "org_params": "nostore_pixiedust", "nostore_bokeh": "false", "prefix": "05fcff58"}, "sniffers": ["{'nostore_bokeh':!!window.Bokeh}"], "avoidMetadata": true, "include_keys": ["filter"]},
#                     {'targetDivId': 'wrapperHTML05fcff58' }
#                 );
#             }
#             )
#             </script>
#
#                 </li>
#
#                 <li id="menu05fcff58-lineChart">
#
#                   <i class="fa fa-line-chart"></i>
#
#                   <span>Line Chart</span>
#
#             <script>
#                 $('#menu05fcff58-lineChart').on('click',
#
#             function(){
#                 pixiedust.executeDisplay(
#                     {"prefix": "05fcff58", "command": "display(Two_Thousands_Movies,cell_id='064dce5964604a988383ef3257a3f235',nostore_pixiedust='true',aggregation='SUM',handlerId='lineChart',keyFields='genres',rowCount='10000',valueFields='avg_rating',nostore_cw='1098',nostore_vh='656',org_params='nostore_pixiedust',nostore_bokeh='false',prefix='05fcff58')", "entity": "Two_Thousands_Movies", "options": {"cell_id": "064dce5964604a988383ef3257a3f235", "nostore_pixiedust": "true", "aggregation": "SUM", "handlerId": "lineChart", "keyFields": "genres", "rowCount": "10000", "valueFields": "avg_rating", "nostore_cw": "1098", "nostore_vh": "656", "org_params": "nostore_pixiedust", "nostore_bokeh": "false", "prefix": "05fcff58"}, "sniffers": ["{'nostore_bokeh':!!window.Bokeh}"], "avoidMetadata": true, "include_keys": ["filter"]},
#                     {'targetDivId': 'wrapperHTML05fcff58' }
#                 );
#             }
#             )
#             </script>
#
#                 </li>
#
#                 <li id="menu05fcff58-scatterPlot">
#
#                   <i class="fa fa-circle"></i>
#
#                   <span>Scatter Plot</span>
#
#             <script>
#                 $('#menu05fcff58-scatterPlot').on('click',
#
#             function(){
#                 pixiedust.executeDisplay(
#                     {"prefix": "05fcff58", "command": "display(Two_Thousands_Movies,cell_id='064dce5964604a988383ef3257a3f235',nostore_pixiedust='true',aggregation='SUM',handlerId='scatterPlot',keyFields='genres',rowCount='10000',valueFields='avg_rating',nostore_cw='1098',nostore_vh='656',org_params='nostore_pixiedust',nostore_bokeh='false',prefix='05fcff58')", "entity": "Two_Thousands_Movies", "options": {"cell_id": "064dce5964604a988383ef3257a3f235", "nostore_pixiedust": "true", "aggregation": "SUM", "handlerId": "scatterPlot", "keyFields": "genres", "rowCount": "10000", "valueFields": "avg_rating", "nostore_cw": "1098", "nostore_vh": "656", "org_params": "nostore_pixiedust", "nostore_bokeh": "false", "prefix": "05fcff58"}, "sniffers": ["{'nostore_bokeh':!!window.Bokeh}"], "avoidMetadata": true, "include_keys": ["filter"]},
#                     {'targetDivId': 'wrapperHTML05fcff58' }
#                 );
#             }
#             )
#             </script>
#
#                 </li>
#
#                 <li id="menu05fcff58-pieChart">
#
#                   <i class="fa fa-pie-chart"></i>
#
#                   <span>Pie Chart</span>
#
#             <script>
#                 $('#menu05fcff58-pieChart').on('click',
#
#             function(){
#                 pixiedust.executeDisplay(
#                     {"prefix": "05fcff58", "command": "display(Two_Thousands_Movies,

# %% [markdown]
# # Movie Recommendation System

# %%
#CloudxLab cant handle huge data for recommendation 

#So,the datasets with less observations are taken for Recommendation system
#The datasets are taken from same MovieLens website
#Reference: https://www.youtube.com/watch?v=rgb6Yy4IGpk&t=485s

# %% [markdown]
# ## Creating Data Frames for Movies and Ratings with Small data

# %%
Ratings_Small= spark.read.option("header", "true").option("delimiter", ",")\
.option("inferSchema", "true").csv("hdfs:///user/imat5322_772599/movies/ratings_small.csv")

# %%
Ratings_Small.show()
# Out:
# +------+-------+------+---------+
# |userId|movieId|rating|timestamp|
# +------+-------+------+---------+
# |     1|      1|   4.0|964982703|
# |     1|      3|   4.0|964981247|
# |     1|      6|   4.0|964982224|
# |     1|     47|   5.0|964983815|
# |     1|     50|   5.0|964982931|
# |     1|     70|   3.0|964982400|
# |     1|    101|   5.0|964980868|
# |     1|    110|   4.0|964982176|
# |     1|    151|   5.0|964984041|
# |     1|    157|   5.0|964984100|
# |     1|    163|   5.0|964983650|
# |     1|    216|   5.0|964981208|
# |     1|    223|   3.0|964980985|
# |     1|    231|   5.0|964981179|
# |     1|    235|   4.0|964980908|
# |     1|    260|   5.0|964981680|
# |     1|    296|   3.0|964982967|
# |     1|    316|   3.0|964982310|
# |     1|    333|   5.0|964981179|
# |     1|    349|   4.0|964982563|
# +------+-------+------+---------+
# only showing top 20 rows

# %%
Movies_Small= spark.read.option("header", "true").option("delimiter", ",")\
.option("inferSchema", "true").csv("hdfs:///user/imat5322_772599/movies/movies_small.csv")

# %%
Movies_Small.show()
# Out:
# +-------+--------------------+--------------------+
# |movieId|               title|              genres|
# +-------+--------------------+--------------------+
# |      1|    Toy Story (1995)|Adventure|Animati...|
# |      2|      Jumanji (1995)|Adventure|Childre...|
# |      3|Grumpier Old Men ...|      Comedy|Romance|
# |      4|Waiting to Exhale...|Comedy|Drama|Romance|
# |      5|Father of the Bri...|              Comedy|
# |      6|         Heat (1995)|Action|Crime|Thri...|
# |      7|      Sabrina (1995)|      Comedy|Romance|
# |      8| Tom and Huck (1995)|  Adventure|Children|
# |      9| Sudden Death (1995)|              Action|
# |     10|    GoldenEye (1995)|Action|Adventure|...|
# |     11|American Presiden...|Comedy|Drama|Romance|
# |     12|Dracula: Dead and...|       Comedy|Horror|
# |     13|        Balto (1995)|Adventure|Animati...|
# |     14|        Nixon (1995)|               Drama|
# |     15|Cutthroat Island ...|Action|Adventure|...|
# |     16|       Casino (1995)|         Crime|Drama|
# |     17|Sense and Sensibi...|       Drama|Romance|
# |     18|   Four Rooms (1995)|              Comedy|
# |     19|Ace Ventura: When...|              Comedy|
# |     20|  Money Train (1995)|Action|Comedy|Cri...|
# +-------+--------------------+--------------------+
# only showing top 20 rows

# %% [markdown]
# ### Cleaning of Data Frame

# %%
Ratings_Small.drop('timestamp')
# Out:
# DataFrame[userId: int, movieId: int, rating: double]

# %% [markdown]
# ## Configuration for Machine Learning

# %%
#Importing machine learning collaborating filtereing Alternative Least Squares

# %%
from pyspark.sql import SparkSession
from pyspark.ml.evaluation import RegressionEvaluator
from pyspark.ml.recommendation import ALS

# %% [markdown]
# ## Splitting the datasets into train and test

# %%
(train,test)=Ratings_Small.randomSplit([0.6,0.4], seed=42)

# %%
train.take(3)
# Out:
# [Row(userId=1, movieId=50, rating=5.0, timestamp=964982931),
#  Row(userId=1, movieId=70, rating=3.0, timestamp=964982400),
#  Row(userId=1, movieId=101, rating=5.0, timestamp=964980868)]

# %%
test.take(3)
# Out:
# [Row(userId=1, movieId=1, rating=4.0, timestamp=964982703),
#  Row(userId=1, movieId=3, rating=4.0, timestamp=964981247),
#  Row(userId=1, movieId=6, rating=4.0, timestamp=964982224)]

# %%
als=ALS(maxIter=5,regParam=0.01,userCol="userId",itemCol="movieId",ratingCol="rating",coldStartStrategy="drop",nonnegative= True)

# %%
#Model creation

model=als.fit(train)

# %%
predictions=model.transform(test)

# %%
evaluator=RegressionEvaluator(metricName="rmse",labelCol="rating",predictionCol="prediction")

# %%
#Root Mean Square Error

rmse=evaluator.evaluate(predictions)

# %%
print("RMSE="+str(rmse))
# Out:
# RMSE=1.0492045710797915

# %%
als=ALS(userCol="userId",itemCol="movieId",ratingCol="rating",coldStartStrategy="drop",nonnegative=True)

# %%
#Creates the matrix

param_grid=ParamGridBuilder().addGrid(als.rank,[5,10,15]).addGrid(als.maxIter,[5,10,15]).addGrid(als.regParam,[0.01,0.05,0.1]).build()

# %%
display(param_grid)
# Out:
# <div class="pixiedust" pixiedust="{&quot;prefix&quot;: &quot;a9caf35e&quot;, &quot;command&quot;: &quot;display(param_grid,cell_id=&apos;68e9c57a1e45458cb9f0e9e7c214da24&apos;,nostore_pixiedust=&apos;true&apos;,aggregation=&apos;COUNT&apos;,handlerId=&apos;tableView&apos;,keyFields=&apos;ALS_ca3757531d30__rank&apos;,rowCount=&apos;100000&apos;,valueFields=&apos;ALS_ca3757531d30__maxIter&apos;,nostore_cw=&apos;1098&apos;,nostore_vh=&apos;656&apos;,org_params=&apos;nostore_pixiedust&apos;,nostore_bokeh=&apos;false&apos;)&quot;, &quot;entity&quot;: &quot;param_grid&quot;, &quot;options&quot;: {&quot;cell_id&quot;: &quot;68e9c57a1e45458cb9f0e9e7c214da24&quot;, &quot;nostore_pixiedust&quot;: &quot;true&quot;, &quot;aggregation&quot;: &quot;COUNT&quot;, &quot;handlerId&quot;: &quot;tableView&quot;, &quot;keyFields&quot;: &quot;ALS_ca3757531d30__rank&quot;, &quot;rowCount&quot;: &quot;100000&quot;, &quot;valueFields&quot;: &quot;ALS_ca3757531d30__maxIter&quot;, &quot;nostore_cw&quot;: &quot;1098&quot;, &quot;nostore_vh&quot;: &quot;656&quot;, &quot;org_params&quot;: &quot;nostore_pixiedust&quot;, &quot;nostore_bokeh&quot;: &quot;false&quot;}, &quot;sniffers&quot;: [&quot;{&apos;nostore_bokeh&apos;:!!window.Bokeh}&quot;], &quot;avoidMetadata&quot;: false, &quot;include_keys&quot;: [&quot;filter&quot;]}">
#
#   <button class="btn btn-default btn-sm expandButton" data-toggle="collapse"
#           data-target="#pixiedust-output-wrapper-a9caf35e" title="Expand/Collapse Pixiedust output">
#     <i class="fa"></i>
#   </button>
#
#
#   <div id="pixiedust-output-wrapper-a9caf35e" class="pixiedust-output-wrapper collapse in">
#
#       <div class="pixiedust-toolbar btn-group" role="group" style="margin-bottom:15px">
#
#
#           <a class="btn btn-small btn-default display-type-button" id="menua9caf35e-tableView" title="Table.Next">
#             <i class="fa fa-table"></i>
#           </a>
#
#             <script>
#                 $('#menua9caf35e-tableView').on('click',
#
#             function(){
#                 pixiedust.executeDisplay(
#                     {"prefix": "a9caf35e", "command": "display(param_grid,cell_id='68e9c57a1e45458cb9f0e9e7c214da24',nostore_pixiedust='true',aggregation='COUNT',handlerId='tableView',keyFields='ALS_ca3757531d30__rank',rowCount='100000',valueFields='ALS_ca3757531d30__maxIter',nostore_cw='1098',nostore_vh='656',org_params='nostore_pixiedust',nostore_bokeh='false',prefix='a9caf35e')", "entity": "param_grid", "options": {"cell_id": "68e9c57a1e45458cb9f0e9e7c214da24", "nostore_pixiedust": "true", "aggregation": "COUNT", "handlerId": "tableView", "keyFields": "ALS_ca3757531d30__rank", "rowCount": "100000", "valueFields": "ALS_ca3757531d30__maxIter", "nostore_cw": "1098", "nostore_vh": "656", "org_params": "nostore_pixiedust", "nostore_bokeh": "false", "prefix": "a9caf35e"}, "sniffers": ["{'nostore_bokeh':!!window.Bokeh}"], "avoidMetadata": true, "include_keys": ["filter"]},
#                     {'targetDivId': 'wrapperHTMLa9caf35e' }
#                 );
#             }
#             )
#             </script>
#
#
#
#
#           <div class="btn-group btn-small display-type-button">
#
#             <a class="btn btn-small dropdown-toggle btn-default" data-toggle="dropdown" title="Chart">
#
#               <i class="fa fa-line-chart"></i>
#
#               <i class="fa fa-chevron-down"></i>
#             </a>
#             <div class="dropdown-menu" role="menu" style="white-space:nowrap">
#               <ul>
#
#                 <li id="menua9caf35e-barChart">
#
#                   <i class="fa fa-bar-chart"></i>
#
#                   <span>Bar Chart</span>
#
#             <script>
#                 $('#menua9caf35e-barChart').on('click',
#
#             function(){
#                 pixiedust.executeDisplay(
#                     {"prefix": "a9caf35e", "command": "display(param_grid,cell_id='68e9c57a1e45458cb9f0e9e7c214da24',nostore_pixiedust='true',aggregation='COUNT',handlerId='barChart',keyFields='ALS_ca3757531d30__rank',rowCount='100000',valueFields='ALS_ca3757531d30__maxIter',nostore_cw='1098',nostore_vh='656',org_params='nostore_pixiedust',nostore_bokeh='false',prefix='a9caf35e')", "entity": "param_grid", "options": {"cell_id": "68e9c57a1e45458cb9f0e9e7c214da24", "nostore_pixiedust": "true", "aggregation": "COUNT", "handlerId": "barChart", "keyFields": "ALS_ca3757531d30__rank", "rowCount": "100000", "valueFields": "ALS_ca3757531d30__maxIter", "nostore_cw": "1098", "nostore_vh": "656", "org_params": "nostore_pixiedust", "nostore_bokeh": "false", "prefix": "a9caf35e"}, "sniffers": ["{'nostore_bokeh':!!window.Bokeh}"], "avoidMetadata": true, "include_keys": ["filter"]},
#                     {'targetDivId': 'wrapperHTMLa9caf35e' }
#                 );
#             }
#             )
#             </script>
#
#                 </li>
#
#                 <li id="menua9caf35e-lineChart">
#
#                   <i class="fa fa-line-chart"></i>
#
#                   <span>Line Chart</span>
#
#             <script>
#                 $('#menua9caf35e-lineChart').on('click',
#
#             function(){
#                 pixiedust.executeDisplay(
#                     {"prefix": "a9caf35e", "command": "display(param_grid,cell_id='68e9c57a1e45458cb9f0e9e7c214da24',nostore_pixiedust='true',aggregation='COUNT',handlerId='lineChart',keyFields='ALS_ca3757531d30__rank',rowCount='100000',valueFields='ALS_ca3757531d30__maxIter',nostore_cw='1098',nostore_vh='656',org_params='nostore_pixiedust',nostore_bokeh='false',prefix='a9caf35e')", "entity": "param_grid", "options": {"cell_id": "68e9c57a1e45458cb9f0e9e7c214da24", "nostore_pixiedust": "true", "aggregation": "COUNT", "handlerId": "lineChart", "keyFields": "ALS_ca3757531d30__rank", "rowCount": "100000", "valueFields": "ALS_ca3757531d30__maxIter", "nostore_cw": "1098", "nostore_vh": "656", "org_params": "nostore_pixiedust", "nostore_bokeh": "false", "prefix": "a9caf35e"}, "sniffers": ["{'nostore_bokeh':!!window.Bokeh}"], "avoidMetadata": true, "include_keys": ["filter"]},
#                     {'targetDivId': 'wrapperHTMLa9caf35e' }
#                 );
#             }
#             )
#             </script>
#
#                 </li>
#
#                 <li id="menua9caf35e-scatterPlot">
#
#                   <i class="fa fa-circle"></i>
#
#                   <span>Scatter Plot</span>
#
#             <script>
#                 $('#menua9caf35e-scatterPlot').on('click',
#
#             function(){
#                 pixiedust.executeDisplay(
#                     {"prefix": "a9caf35e", "command": "display(param_grid,cell_id='68e9c57a1e45458cb9f0e9e7c214da24',nostore_pixiedust='true',aggregation='COUNT',handlerId='scatterPlot',keyFields='ALS_ca3757531d30__rank',rowCount='100000',valueFields='ALS_ca3757531d30__maxIter',nostore_cw='1098',nostore_vh='656',org_params='nostore_pixiedust',nostore_bokeh='false',prefix='a9caf35e')", "entity": "param_grid", "options": {"cell_id": "68e9c57a1e45458cb9f0e9e7c214da24", "nostore_pixiedust": "true", "aggregation": "COUNT", "handlerId": "scatterPlot", "keyFields": "ALS_ca3757531d30__rank", "rowCount": "100000", "valueFields": "ALS_ca3757531d30__maxIter", "nostore_cw": "1098", "nostore_vh": "656", "org_params": "nostore_pixiedust", "nostore_bokeh": "false", "prefix": "a9caf35e"}, "sniffers": ["{'nostore_bokeh':!!window.Bokeh}"], "avoidMetadata": true, "include_keys": ["filter"]},
#                     {'targetDivId': 'wrapperHTMLa9caf35e' }
#                 );
#             }
#             )
#             </script>
#
#                 </li>
#
#                 <li id="menua9caf35e-pieChart">
#
#                   <i class="fa fa-pie-chart"></i>
#
#                   <span>Pie Chart</span>

# %%
evaluator=RegressionEvaluator(metricName="rmse",labelCol="rating",predictionCol="prediction")

# %%
display(evaluator)
# Out:
# RegressionEvaluator_f06d4c5cc968

# %%
Train_Validate_Split=TrainValidationSplit(estimator=als,estimatorParamMaps=param_grid,evaluator=evaluator)

# %%
model=Train_Validate_Split.fit(train)

# %%
Best_Model=model.bestModel
predictions=Best_Model.transform(test)
rmse=evaluator.evaluate(predictions)

# %%
print("RMSE="+str(rmse))
print("Rank="+str(Best_Model.rank))
print("MaxIter="+str(Best_Model._java_obj.parent().getMaxIter()))
print("RegParam="+str(Best_Model._java_obj.parent().getRegParam()))
# Out:
# RMSE=0.9069665545520337
# Rank=10
# MaxIter=10
# RegParam=0.1

# %%
User=Best_Model.recommendForAllUsers(10).sort("userId")

# %%
display(User)
# Out:
# <div class="pixiedust" pixiedust="{&quot;prefix&quot;: &quot;119b9587&quot;, &quot;command&quot;: &quot;display(User,cell_id=&apos;3bf91e749f754ce79fdd39b1a2b32f14&apos;,nostore_pixiedust=&apos;true&apos;,handlerId=&apos;tableView&apos;,nostore_cw=&apos;1098&apos;,nostore_vh=&apos;656&apos;,org_params=&apos;nostore_pixiedust&apos;,nostore_bokeh=&apos;false&apos;)&quot;, &quot;entity&quot;: &quot;User&quot;, &quot;options&quot;: {&quot;cell_id&quot;: &quot;3bf91e749f754ce79fdd39b1a2b32f14&quot;, &quot;nostore_pixiedust&quot;: &quot;true&quot;, &quot;handlerId&quot;: &quot;tableView&quot;, &quot;nostore_cw&quot;: &quot;1098&quot;, &quot;nostore_vh&quot;: &quot;656&quot;, &quot;org_params&quot;: &quot;nostore_pixiedust&quot;, &quot;nostore_bokeh&quot;: &quot;false&quot;}, &quot;sniffers&quot;: [&quot;{&apos;nostore_bokeh&apos;:!!window.Bokeh}&quot;], &quot;avoidMetadata&quot;: false, &quot;include_keys&quot;: [&quot;filter&quot;]}">
#
#   <button class="btn btn-default btn-sm expandButton" data-toggle="collapse"
#           data-target="#pixiedust-output-wrapper-119b9587" title="Expand/Collapse Pixiedust output">
#     <i class="fa"></i>
#   </button>
#
#
#   <div id="pixiedust-output-wrapper-119b9587" class="pixiedust-output-wrapper collapse in">
#
#       <div class="pixiedust-toolbar btn-group" role="group" style="margin-bottom:15px">
#
#
#           <a class="btn btn-small btn-default display-type-button" id="menu119b9587-tableView" title="Table.Next">
#             <i class="fa fa-table"></i>
#           </a>
#
#             <script>
#                 $('#menu119b9587-tableView').on('click',
#
#             function(){
#                 pixiedust.executeDisplay(
#                     {"prefix": "119b9587", "command": "display(User,cell_id='3bf91e749f754ce79fdd39b1a2b32f14',nostore_pixiedust='true',handlerId='tableView',nostore_cw='1098',nostore_vh='656',org_params='nostore_pixiedust',nostore_bokeh='false',prefix='119b9587')", "entity": "User", "options": {"cell_id": "3bf91e749f754ce79fdd39b1a2b32f14", "nostore_pixiedust": "true", "handlerId": "tableView", "nostore_cw": "1098", "nostore_vh": "656", "org_params": "nostore_pixiedust", "nostore_bokeh": "false", "prefix": "119b9587"}, "sniffers": ["{'nostore_bokeh':!!window.Bokeh}"], "avoidMetadata": true, "include_keys": ["filter"]},
#                     {'targetDivId': 'wrapperHTML119b9587' }
#                 );
#             }
#             )
#             </script>
#
#
#
#
#           <div class="btn-group btn-small display-type-button">
#
#             <a class="btn btn-small dropdown-toggle btn-default" data-toggle="dropdown" title="Chart">
#
#               <i class="fa fa-line-chart"></i>
#
#               <i class="fa fa-chevron-down"></i>
#             </a>
#             <div class="dropdown-menu" role="menu" style="white-space:nowrap">
#               <ul>
#
#                 <li id="menu119b9587-barChart">
#
#                   <i class="fa fa-bar-chart"></i>
#
#                   <span>Bar Chart</span>
#
#             <script>
#                 $('#menu119b9587-barChart').on('click',
#
#             function(){
#                 pixiedust.executeDisplay(
#                     {"prefix": "119b9587", "command": "display(User,cell_id='3bf91e749f754ce79fdd39b1a2b32f14',nostore_pixiedust='true',handlerId='barChart',nostore_cw='1098',nostore_vh='656',org_params='nostore_pixiedust',nostore_bokeh='false',prefix='119b9587')", "entity": "User", "options": {"cell_id": "3bf91e749f754ce79fdd39b1a2b32f14", "nostore_pixiedust": "true", "handlerId": "barChart", "nostore_cw": "1098", "nostore_vh": "656", "org_params": "nostore_pixiedust", "nostore_bokeh": "false", "prefix": "119b9587"}, "sniffers": ["{'nostore_bokeh':!!window.Bokeh}"], "avoidMetadata": true, "include_keys": ["filter"]},
#                     {'targetDivId': 'wrapperHTML119b9587' }
#                 );
#             }
#             )
#             </script>
#
#                 </li>
#
#                 <li id="menu119b9587-lineChart">
#
#                   <i class="fa fa-line-chart"></i>
#
#                   <span>Line Chart</span>
#
#             <script>
#                 $('#menu119b9587-lineChart').on('click',
#
#             function(){
#                 pixiedust.executeDisplay(
#                     {"prefix": "119b9587", "command": "display(User,cell_id='3bf91e749f754ce79fdd39b1a2b32f14',nostore_pixiedust='true',handlerId='lineChart',nostore_cw='1098',nostore_vh='656',org_params='nostore_pixiedust',nostore_bokeh='false',prefix='119b9587')", "entity": "User", "options": {"cell_id": "3bf91e749f754ce79fdd39b1a2b32f14", "nostore_pixiedust": "true", "handlerId": "lineChart", "nostore_cw": "1098", "nostore_vh": "656", "org_params": "nostore_pixiedust", "nostore_bokeh": "false", "prefix": "119b9587"}, "sniffers": ["{'nostore_bokeh':!!window.Bokeh}"], "avoidMetadata": true, "include_keys": ["filter"]},
#                     {'targetDivId': 'wrapperHTML119b9587' }
#                 );
#             }
#             )
#             </script>
#
#                 </li>
#
#                 <li id="menu119b9587-scatterPlot">
#
#                   <i class="fa fa-circle"></i>
#
#                   <span>Scatter Plot</span>
#
#             <script>
#                 $('#menu119b9587-scatterPlot').on('click',
#
#             function(){
#                 pixiedust.executeDisplay(
#                     {"prefix": "119b9587", "command": "display(User,cell_id='3bf91e749f754ce79fdd39b1a2b32f14',nostore_pixiedust='true',handlerId='scatterPlot',nostore_cw='1098',nostore_vh='656',org_params='nostore_pixiedust',nostore_bokeh='false',prefix='119b9587')", "entity": "User", "options": {"cell_id": "3bf91e749f754ce79fdd39b1a2b32f14", "nostore_pixiedust": "true", "handlerId": "scatterPlot", "nostore_cw": "1098", "nostore_vh": "656", "org_params": "nostore_pixiedust", "nostore_bokeh": "false", "prefix": "119b9587"}, "sniffers": ["{'nostore_bokeh':!!window.Bokeh}"], "avoidMetadata": true, "include_keys": ["filter"]},
#                     {'targetDivId': 'wrapperHTML119b9587' }
#                 );
#             }
#             )
#             </script>
#
#                 </li>
#
#                 <li id="menu119b9587-pieChart">
#
#                   <i class="fa fa-pie-chart"></i>
#
#                   <span>Pie Chart</span>
#
#             <script>
#                 $('#menu119b9587-pieChart').on('click',
#
#             function(){
#                 pixiedust.executeDisplay(
#                     {"prefix": "119b9587", "command": "display(User,cell_id='3bf91e749f754ce79fdd39b1a2b32f14',nostore_pixiedust='true',handlerId='pieChart',nostore_cw='1098',nostore_vh='656',org_params='nostore_pixiedust',nostore_bokeh='false',prefix='119b9587')", "entity": "User", "options": {"cell_id": "3bf91e749f754ce79fdd39b1a2b32f14", "nostore_pixiedust": "true", "handlerId": "pieChart", "nostore_cw": "1098", "nostore_vh": "656", "org_params": "nostore_pixiedust", "nostore_bokeh": "false", "prefix": "119b9587"}, "sniffers": ["{'nostore_bokeh':!!window.Bokeh}"], "avoidMetadata": true, "include_keys": ["filter"]},
#                     {'targetDivId': 'wrapperHTML119b9587' }
#                 );
#             }
#             )
#             </script>
#
#                 </li>
#
#                 <li id="menu119b9587-mapView">
#
#                   <i class="fa fa-globe"></i>
#
#                   <span>Map</span>
#
#             <script>
#                 $('#menu119b9587-mapView').on('click',
#
#             function(){
#                 pixiedust.executeDisplay(
#                     {"prefix": "119b9587", "command": "display(User,cell_id='3bf91e749f754

# %%
predictions.sort("userId","rating").show()
# Out:
# +------+-------+------+---------+----------+
# |userId|movieId|rating|timestamp|prediction|
# +------+-------+------+---------+----------+
# |     1|   2253|   2.0|964981775| 2.7571738|
# |     1|   1219|   2.0|964983393| 4.7502465|
# |     1|   2389|   2.0|964983094| 2.1207445|
# |     1|   2617|   2.0|964982588| 3.9391813|
# |     1|   2093|   3.0|964981710| 3.9147518|
# |     1|   3247|   3.0|964983108| 3.4347394|
# |     1|   2657|   3.0|964983426| 3.7289064|
# |     1|   1030|   3.0|964982903|  3.333755|
# |     1|    296|   3.0|964982967|  4.679693|
# |     1|   3243|   3.0|964981093| 3.0422611|
# |     1|    316|   3.0|964982310| 3.7368307|
# |     1|   2414|   3.0|964982513| 3.9527335|
# |     1|   1377|   3.0|964982653| 3.6174746|
# |     1|   1676|   3.0|964982620| 3.7719731|
# |     1|   2640|   4.0|964982377|  4.151831|
# |     1|   2096|   4.0|964982838|  4.060938|
# |     1|    552|   4.0|964982653|  3.936318|
# |     1|   3440|   4.0|964981799|  2.723496|
# |     1|    590|   4.0|964982546| 4.4870934|
# |     1|    593|   4.0|964983793|  4.866274|
# +------+-------+------+---------+----------+
# only showing top 20 rows

# %%
#Creating a function

def get_rec(rec):
  rec=rec.select("userId",explode(rec.recommendations))
  rec=rec.select("col.*","*")
  Func_Rating=rec.select(["userId","movieId","rating"])
  return Func_Rating

# %%
Func_Rating=get_rec(Best_Model.recommendForAllUsers(10))

# %%
Func_Rating.show()
# Out:
# +------+-------+---------+
# |userId|movieId|   rating|
# +------+-------+---------+
# |   471| 177593|4.9599953|
# |   471|   2511|4.9179683|
# |   471|   2936|4.8650985|
# |   471|  26258| 4.849306|
# |   471|   1104| 4.781372|
# |   471|   2351| 4.748386|
# |   471|  33779| 4.729414|
# |   471|  92494| 4.729414|
# |   471|   3083| 4.702852|
# |   471|    334| 4.686756|
# |   463|   7842| 4.994829|
# |   463|   3030| 4.887071|
# |   463| 171495| 4.823522|
# |   463|    441|4.8196015|
# |   463| 175303|  4.79199|
# |   463|    951|4.7730403|
# |   463|   5952|4.7091293|
# |   463| 115713|4.6827116|
# |   463|  26133| 4.680236|
# |   463|   6300|4.6791954|
# +------+-------+---------+
# only showing top 20 rows

# %% [markdown]
# ## Movies Watched

# %%
Movies_Watched=Func_Rating.join(Movies_Small,['movieId'],how='left')

# %%
Movies_Watched.filter("userId=20").orderBy(Movies_Watched["rating"].desc()).show(10)
# Out:
# +-------+------+---------+--------------------+------------------+
# |movieId|userId|   rating|               title|            genres|
# +-------+------+---------+--------------------+------------------+
# |   5915|    20| 5.558968|Victory (a.k.a. E...|  Action|Drama|War|
# | 132333|    20| 5.558968|         Seve (2014)| Documentary|Drama|
# |   5490|    20| 5.558968|  The Big Bus (1976)|     Action|Comedy|
# | 177593|    20| 5.516726|Three Billboards ...|       Crime|Drama|
# |   1949|    20|5.4781146|Man for All Seaso...|             Drama|
# |   4429|    20| 5.452118|    Moby Dick (1956)|             Drama|
# |   6375|    20| 5.383952|Gigantic (A Tale ...|       Documentary|
# |   2202|    20| 5.322255|     Lifeboat (1944)|         Drama|War|
# |  92494|    20|5.2772484|Dylan Moran: Mons...|Comedy|Documentary|
# |  33779|    20|5.2772484|Eddie Izzard: Dre...|            Comedy|
# +-------+------+---------+--------------------+------------------+

# %% [markdown]
# ## Movies Recommended

# %%
Movies_Recommended=Movies_Small.join(Ratings_Small,['movieId'],how='left')
Movies_Recommended.filter("userId=20").orderBy(Movies_Recommended["rating"].desc()).show(10)
# Out:
# +-------+--------------------+--------------------+------+------+----------+
# |movieId|               title|              genres|userId|rating| timestamp|
# +-------+--------------------+--------------------+------+------+----------+
# |    919|Wizard of Oz, The...|Adventure|Childre...|    20|   5.0|1054038078|
# |   2083|Muppet Christmas ...|Children|Comedy|M...|    20|   5.0|1054038103|
# |   1025|Sword in the Ston...|Animation|Childre...|    20|   5.0|1054038107|
# |    720|Wallace & Gromit:...|Adventure|Animati...|    20|   5.0|1054038502|
# |   1073|Willy Wonka & the...|Children|Comedy|F...|    20|   5.0|1054038071|
# |    551|Nightmare Before ...|Animation|Childre...|    20|   5.0|1054038128|
# |   1097|E.T. the Extra-Te...|Children|Drama|Sc...|    20|   5.0|1054038065|
# |    594|Snow White and th...|Animation|Childre...|    20|   5.0|1054038083|
# |   1148|Wallace & Gromit:...|Animation|Childre...|    20|   5.0|1054038506|
# |    661|James and the Gia...|Adventure|Animati...|    20|   5.0|1054038185|
# +-------+--------------------+--------------------+------+------+----------+
# only showing top 10 rows
